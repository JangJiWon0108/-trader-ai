# %% [markdown]
# # 주가 예측 모델 (Transformer)
#
# ## ⚙️ 실행 전 설정
# - `TEST_MODE = True` → 로컬 소규모 테스트 (빠름)
# - `TEST_MODE = False` → Google Colab 실제 학습 (전체 데이터, GPU)
# - `IS_LOCAL = True` → 모델을 `model/` 로컬 경로에 저장
# - `IS_LOCAL = False` → Google Drive 경로에 저장

# %%
# ============================================================
# 실행 설정 변수 — 여기만 수정하면 됩니다
# ============================================================
#
# TEST_MODE:
#   True  → 최신 100행, epoch 2회로 빠르게 동작 확인용 (로컬 테스트)
#   False → 전체 데이터, epoch 50회로 실제 학습 (Google Colab 권장)
#
# IS_LOCAL:
#   True  → 로컬 ../model/ 경로에 모델 저장
#   False → Google Colab 환경에서 Google Drive 경로에 저장

TEST_MODE = False
IS_LOCAL  = False

# 로컬 저장 경로 (IS_LOCAL=True 일 때 사용)
LOCAL_MODEL_DIR = "../model"

# Google Drive 저장 경로 (IS_LOCAL=False, Colab 환경일 때 사용)
DRIVE_MODEL_DIR = "/content/drive/MyDrive/trader-ai/model/v2_260505"
# 학습 업데이트 시 아래 추가 후, 돌림 (학습날짜 별로 모델 관리)
# DRIVE_MODEL_DIR = "/content/drive/MyDrive/trader-ai/model/v2_260505"

# 위 두 설정에 따라 실제 저장 경로 자동 결정
MODEL_DIR = LOCAL_MODEL_DIR if IS_LOCAL else DRIVE_MODEL_DIR

# ── 하이퍼파라미터 ──────────────────────────────────────────
# TEST_MODE에 따라 자동으로 값이 달라집니다
# LOOKBACK         : 모델이 과거 며칠치 데이터를 보고 예측할지
# FORECAST_HORIZON : 며칠 뒤 주가를 예측할지
# EPOCHS           : 학습 반복 횟수 (많을수록 정확하지만 오래 걸림)
# BATCH_SIZE       : 한 번에 학습할 데이터 샘플 수
if TEST_MODE:
    DATA_LIMIT       = 100   # 테스트용 소량 데이터 (최신 100행)
    LOOKBACK         = 20    # 과거 20일 데이터를 입력으로 사용
    FORECAST_HORIZON = 5     # 5일 뒤 주가 예측
    EPOCHS           = 2
    BATCH_SIZE       = 8
else:
    DATA_LIMIT       = None  # 전체 데이터 사용
    LOOKBACK         = 90    # 과거 90일(약 3개월)
    FORECAST_HORIZON = 14    # 2주 뒤 주가 예측
    EPOCHS           = 50
    BATCH_SIZE       = 32

print(f"TEST_MODE        : {TEST_MODE}")
print(f"IS_LOCAL         : {IS_LOCAL}")
print(f"MODEL_DIR        : {MODEL_DIR}")
print(f"DATA_LIMIT       : {DATA_LIMIT}")
print(f"LOOKBACK         : {LOOKBACK}")
print(f"FORECAST_HORIZON : {FORECAST_HORIZON}")
print(f"EPOCHS           : {EPOCHS}")
# Out:
# TEST_MODE        : False
# IS_LOCAL         : False
# MODEL_DIR        : /content/drive/MyDrive/trader-ai/model/v2_260505
# DATA_LIMIT       : None
# LOOKBACK         : 90
# FORECAST_HORIZON : 14
# EPOCHS           : 50

# %% [markdown]
# ## 1. 환경 설정

# %%
# Google Colab 환경(IS_LOCAL=False)일 때만 실행되는 초기화 블록
# - Google Drive를 마운트해서 모델 저장 경로를 사용할 수 있게 함
# - Colab 기본 환경에 없는 패키지(supabase, scikit-learn)를 설치
if not IS_LOCAL:
    from google.colab import drive
    drive.mount('/content/drive')
    import subprocess
    subprocess.run(['pip', 'install', 'supabase', 'scikit-learn'], check=True)

import os
# 모델을 저장할 디렉토리가 없으면 자동 생성
os.makedirs(MODEL_DIR, exist_ok=True)
print(f"모델 저장 경로 준비 완료: {MODEL_DIR}")
# Out:
# Mounted at /content/drive
# 모델 저장 경로 준비 완료: /content/drive/MyDrive/trader-ai/model/v2_260505

# %%
# ── 데이터 처리 ──────────────────────────────────────────────
import joblib          # 스케일러(.pkl) 저장/로드
import numpy as np
import pandas as pd

# ── 전처리 & 평가 지표 ──────────────────────────────────────
from sklearn.preprocessing import MinMaxScaler          # 0~1 정규화
from sklearn.metrics import mean_absolute_error, mean_squared_error

# ── DB 연결 ─────────────────────────────────────────────────
from supabase import create_client, Client   # Supabase(PostgreSQL) 클라이언트

# ── 딥러닝 모델 (Transformer) ────────────────────────────────
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, LayerNormalization,
    MultiHeadAttention,   # Transformer의 핵심 — 시퀀스 내 각 시점간 관계 학습
    Add, GlobalAveragePooling1D
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint  # 과적합 방지

# ── 시각화 ──────────────────────────────────────────────────
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

print(f"TensorFlow: {tf.__version__}")
print(f"GPU 사용 가능: {len(tf.config.list_physical_devices('GPU')) > 0}")
# Out:
# TensorFlow: 2.20.0
# GPU 사용 가능: True

# %% [markdown]
# ## 2. Supabase 연결

# %%
# Supabase는 이 프로젝트의 데이터베이스 역할을 합니다
# - 학습 원본 데이터(주가 + 경제지표)를 읽어옴
# - 예측 결과를 저장해서 트레이딩 앱이 읽어갈 수 있게 함
#
# service_role 키: RLS(Row Level Security)를 우회하여 읽기/쓰기 모두 가능
# 주의: 이 키는 외부에 노출되면 안 됩니다

SUPABASE_URL         = "https://cubyfztyjnyqbsiemhay.supabase.co"
SUPABASE_SERVICE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImN1YnlmenR5am55cWJzaWVtaGF5Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc3NzgwMTgxMiwiZXhwIjoyMDkzMzc3ODEyfQ.1I1StMUdPfRVsHDNaKPAUcR70AJVJ-_25pdjPS_O4J8"

supabase       = create_client(SUPABASE_URL, SUPABASE_SERVICE_KEY)
supabase_admin = supabase   # 읽기/쓰기 모두 같은 클라이언트 사용
print("Supabase 연결 완료 (service_role)")
# Out:
# Supabase 연결 완료 (service_role)

# %% [markdown]
# ## 3. 데이터 로드

# %%
def get_all_rows(table_name, limit_rows=None, chunk=1000, latest_first=False):
    """
    Supabase 테이블에서 전체 데이터를 페이지 단위로 가져옵니다.

    Args:
        table_name   : 조회할 테이블 이름
        limit_rows   : 최대 로드 행 수 (None이면 전체)
        chunk        : 한 번에 가져올 행 수
        latest_first : True이면 최신 데이터부터 가져옴 (TEST_MODE용)
    """
    # latest_first=True면 최신 데이터부터 가져와서 limit 이후 재정렬
    order_desc = latest_first and (limit_rows is not None)
    all_data, offset = [], 0
    while True:
        fetch = min(chunk, limit_rows - len(all_data)) if limit_rows else chunk
        resp = (
            supabase.table(table_name)
            .select("*")
            .order("날짜", desc=order_desc)
            .limit(fetch)
            .offset(offset)
            .execute()
        )
        if not resp.data:
            break
        all_data.extend(resp.data)
        if limit_rows and len(all_data) >= limit_rows:
            break
        offset += chunk
    return all_data


def load_data(limit_rows=None):
    """
    economic_and_stock_data 테이블에서 데이터를 로드하고 전처리합니다.

    전처리 순서:
      1. 날짜 파싱 및 오름차순 정렬
      2. ffill/bfill: 누락된 값을 앞뒤 값으로 채움 (주말/공휴일 등 결측치 처리)
      3. 숫자 변환: 문자열로 저장된 수치를 float으로 변환
      4. 100% NaN인 컬럼 제외 후 dropna
    """
    # limit_rows가 있으면 최신 데이터부터 가져옴 (2006년 오래된 데이터 방지)
    rows = get_all_rows("economic_and_stock_data", limit_rows=limit_rows, latest_first=(limit_rows is not None))
    df = pd.DataFrame(rows)
    df['날짜'] = pd.to_datetime(df['날짜'])
    df.sort_values('날짜', inplace=True)   # 최신 우선으로 가져왔으므로 다시 오름차순 정렬
    df = df.ffill().bfill()
    numeric_cols = [c for c in df.columns if c != '날짜']
    df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
    nan_ratios = df[numeric_cols].isna().mean()
    valid_cols = nan_ratios[nan_ratios < 1.0].index.tolist()
    df.dropna(subset=valid_cols, inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

# %%
# 위에서 정의한 함수로 실제 데이터를 불러옵니다
# TEST_MODE=True 이면 DATA_LIMIT=100 행만 로드 (최신 데이터 기준, 빠른 테스트용)
# TEST_MODE=False 이면 전체 기간 데이터 로드
print(f"데이터 로드 중... (limit={DATA_LIMIT})")
data = load_data(limit_rows=DATA_LIMIT)

print(f"로드 완료: {len(data):,}행 × {len(data.columns)}컬럼")
print(f"기간: {data['날짜'].min().date()} ~ {data['날짜'].max().date()}")
data.head(3)
# Out:
# 데이터 로드 중... (limit=None)
# 로드 완료: 7,429행 × 88컬럼
# 기간: 2006-01-01 ~ 2026-05-04
#           날짜  10년 기대 인플레이션율  장단기 금리차  기준금리  미시간대 소비자 심리지수  실업률  \
# 0 2006-01-01           2.34     0.03  4.29           91.2  4.7
# 1 2006-01-02           2.34     0.03  4.29           91.2  4.7
# 2 2006-01-03           2.34     0.03  4.29           91.2  4.7
#
#    2년 만기 미국 국채 수익률  10년 만기 미국 국채 수익률  금융스트레스지수  개인 소비 지출  ...  버텍스 파마슈티컬스  \
# 0             4.34              4.37   -0.8478    9071.6  ...        27.9
# 1             4.34              4.37   -0.8478    9071.6  ...        27.9
# 2             4.34              4.37   -0.8478    9071.6  ...        27.9
#
#      어도비      컴캐스트       케이던스       시놉시스      메리어트  메르카도리브레        ADP  \
# 0  38.52  8.194314  16.950001  20.459999  31.46693     28.5  36.742661
# 1  38.52  8.194314  16.950001  20.459999  31.46693     28.5  36.742661
# 2  38.52  8.194314  16.950001  20.459999  31.46693     28.5  36.742661
#
#         에어비앤비       몬델리즈
# 0  144.710007  28.049999
# 1  144.710007  28.049999
# 2  144.710007  28.049999
#
# [3 rows x 88 columns]

# %%
# 결측치
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (7429, 88)

# %% [markdown]
# ## 4. 피처 정의

# %%
# ── 예측 대상(Target) ─────────────────────────────────────────
# 나스닥 50개 종목 — 모델 출력(y)
TARGET_COLUMNS = [
    '엔비디아', '구글 A', '애플', '마이크로소프트', '아마존',
    '브로드컴', '메타', '테슬라', '월마트', '마이크론',
    'AMD', 'ASML', '인텔', '코스트코', '넷플릭스',
    '시스코', '팔란티어', '램리서치', '어플라이드 머티리얼즈', '텍사스 인스트루먼트',
    '린드', 'KLA Corp', 'Arm', '펩시코', '티모바일',
    '아나로그디바이스', '샌디스크', '퀄컴', '암젠', '쇼피파이',
    '씨게이트', '인튜이티브 서지컬', '앱러빈', '팔로알토 네트웍스', '마벨 테크놀로지',
    '허니웰 인터내셔널', '부킹홀딩스', '스타벅스', '콘스텔레이션 에너지', '인튜이트',
    '버텍스 파마슈티컬스', '어도비', '컴캐스트', '케이던스', '시놉시스',
    '메리어트', '메르카도리브레', 'ADP', '에어비앤비', '몬델리즈',
]

# ── 입력 피처(Feature) ────────────────────────────────────────
# 거시경제 지표 + 글로벌 지수/ETF/환율 — 모델 보조 입력(econ_input)
ECONOMIC_FEATURES = [
    '10년 기대 인플레이션율', '장단기 금리차', '기준금리', '미시간대 소비자 심리지수',
    '실업률', '2년 만기 미국 국채 수익률', '10년 만기 미국 국채 수익률', '금융스트레스지수',
    '개인 소비 지출', '소비자 물가지수', '5년 변동금리 모기지', '미국 달러 환율',
    '통화 공급량 M2', '가계 부채 비율', 'GDP 성장률',
    '나스닥 종합지수', 'S&P 500 지수', '금 가격', '달러 인덱스', '나스닥 100',
    'S&P 500 ETF', 'QQQ ETF', '러셀 2000 ETF', '다우 존스 ETF', 'VIX 지수',
    '닛케이 225', '상해종합', '항셍', '영국 FTSE', '독일 DAX', '프랑스 CAC 40',
    '미국 전체 채권시장 ETF', 'TIPS ETF', '투자등급 회사채 ETF', '달러/엔', '달러/위안',
    '미국 리츠 ETF'
]

# 실제 DB에서 로드된 컬럼에 없는 항목은 제외 (데이터 누락 방어)
TARGET_COLUMNS    = [c for c in TARGET_COLUMNS    if c in data.columns]
ECONOMIC_FEATURES = [c for c in ECONOMIC_FEATURES if c in data.columns]

print(f"예측 대상 종목 : {len(TARGET_COLUMNS)}개")
print(f"경제 지표 피처 : {len(ECONOMIC_FEATURES)}개")
print(f"LOOKBACK       : {LOOKBACK}일")
print(f"FORECAST_HORIZON: {FORECAST_HORIZON}일 후")
# Out:
# 예측 대상 종목 : 50개
# 경제 지표 피처 : 37개
# LOOKBACK       : 90일
# FORECAST_HORIZON: 14일 후

# %% [markdown]
# ## 5. 스케일링 및 데이터셋 구성

# %%
# 신경망은 입력값의 범위가 일정해야 학습이 잘 됩니다.
# MinMaxScaler: 각 컬럼의 최솟값→0, 최댓값→1 으로 변환 (0~1 정규화)
#
# 주가와 경제지표는 단위/스케일이 서로 달라 별도 스케일러를 사용합니다.
# 나중에 예측 결과를 원래 가격으로 되돌릴 때(inverse_transform) 이 스케일러가 필요합니다.

data_scaled  = data.copy()
stock_scaler = MinMaxScaler()   # 주가 전용 스케일러 (저장 대상)
econ_scaler  = MinMaxScaler()   # 경제지표 전용 스케일러 (저장 대상)

data_scaled[TARGET_COLUMNS]    = stock_scaler.fit_transform(data[TARGET_COLUMNS])
data_scaled[ECONOMIC_FEATURES] = econ_scaler.fit_transform(data[ECONOMIC_FEATURES])

print("스케일링 완료")
# Out:
# 스케일링 완료

# %%
# 학습용 슬라이딩 윈도우 데이터셋 구성
#
# 구조:
#   X_stock_train[i] = 날짜 i 기준 과거 LOOKBACK일간 주가 시퀀스   (shape: LOOKBACK × 종목수)
#   X_econ_train[i]  = 날짜 i 기준 과거 LOOKBACK일간 경제지표 시퀀스 (shape: LOOKBACK × 지표수)
#   y_train[i]       = 날짜 i + FORECAST_HORIZON일 후의 주가         (shape: 종목수)
#
# 예) LOOKBACK=90, FORECAST_HORIZON=14 일 때
#   → 과거 90일 데이터를 보고 14일 뒤 주가를 맞추도록 학습
#
# 마지막 FORECAST_HORIZON개 행은 정답(y)이 존재하지 않아 학습에서 제외됩니다.

X_stock_train, X_econ_train, y_train = [], [], []

for i in range(LOOKBACK, len(data_scaled) - FORECAST_HORIZON):
    X_stock_train.append(data_scaled[TARGET_COLUMNS].iloc[i-LOOKBACK:i].to_numpy())
    X_econ_train.append(data_scaled[ECONOMIC_FEATURES].iloc[i-LOOKBACK:i].to_numpy())
    y_train.append(data_scaled[TARGET_COLUMNS].iloc[i+FORECAST_HORIZON-1].to_numpy())

X_stock_train = np.array(X_stock_train)
X_econ_train  = np.array(X_econ_train)
y_train       = np.array(y_train)

print(f"X_stock_train : {X_stock_train.shape}")   # (샘플수, LOOKBACK, 종목수)
print(f"X_econ_train  : {X_econ_train.shape}")    # (샘플수, LOOKBACK, 지표수)
print(f"y_train       : {y_train.shape}")         # (샘플수, 종목수)
# Out:
# X_stock_train : (7325, 90, 50)
# X_econ_train  : (7325, 90, 37)
# y_train       : (7325, 50)

# %%
# 전체 구간 예측용 데이터셋 구성 (학습 후 결과 시각화/DB 저장에 사용)
#
# 학습셋과 달리 미래 정답(y)이 필요 없으므로
# FORECAST_HORIZON 제한 없이 모든 날짜에 대해 윈도우를 만듭니다.
# 이 데이터로 model.predict()를 호출하면 각 날짜에서 FORECAST_HORIZON일 뒤 예측값을 얻습니다.

X_stock_full, X_econ_full = [], []

for i in range(LOOKBACK, len(data_scaled)):
    X_stock_full.append(data_scaled[TARGET_COLUMNS].iloc[i-LOOKBACK:i].to_numpy())
    X_econ_full.append(data_scaled[ECONOMIC_FEATURES].iloc[i-LOOKBACK:i].to_numpy())

X_stock_full = np.array(X_stock_full)
X_econ_full  = np.array(X_econ_full)

print(f"X_stock_full : {X_stock_full.shape}")
print(f"X_econ_full  : {X_econ_full.shape}")
# Out:
# X_stock_full : (7339, 90, 50)
# X_econ_full  : (7339, 90, 37)

# %% [markdown]
# ## 6. Transformer 모델 정의 및 학습

# %%
def transformer_encoder(inputs, num_heads, ff_dim, dropout=0.3):
    attn = MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1])(inputs, inputs)
    attn = Dropout(dropout)(attn)
    attn = Add()([inputs, attn])
    attn = LayerNormalization(epsilon=1e-6)(attn)
    ffn  = Dense(ff_dim, activation="relu")(attn)
    ffn  = Dense(inputs.shape[-1])(ffn)
    ffn  = Dropout(dropout)(ffn)
    ffn  = Add()([attn, ffn])
    ffn  = LayerNormalization(epsilon=1e-6)(ffn)
    return ffn


def build_model(stock_shape, econ_shape, num_heads=8, ff_dim=256, num_layers=4):
    stock_in = Input(shape=stock_shape, name="stock_input")
    x = stock_in
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, ff_dim)
    x = Dense(64, activation="relu")(x)

    econ_in = Input(shape=econ_shape, name="econ_input")
    y = econ_in
    for _ in range(num_layers):
        y = transformer_encoder(y, num_heads, ff_dim)
    y = Dense(64, activation="relu")(y)

    merged = Add()([x, y])
    merged = Dense(128, activation="relu")(merged)
    merged = Dropout(0.4)(merged)
    merged = GlobalAveragePooling1D()(merged)
    output = Dense(stock_shape[1], name="output")(merged)
    return Model(inputs=[stock_in, econ_in], outputs=output)


print("모델 함수 정의 완료 (dropout=0.3/0.4)")
# Out:
# 모델 함수 정의 완료 (dropout=0.3/0.4)

# %%
# 입력 shape 정의
# stock_shape: (LOOKBACK일, 종목 수) — 주가 시퀀스
# econ_shape : (LOOKBACK일, 경제지표 수) — 경제지표 시퀀스
stock_shape = (LOOKBACK, len(TARGET_COLUMNS))
econ_shape  = (LOOKBACK, len(ECONOMIC_FEATURES))

model = build_model(stock_shape, econ_shape)

# loss='mse': 예측값과 실제값의 차이(제곱 평균)를 최소화
# mae: 평균 절대 오차 — 학습 중 참고용 지표
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])
model.summary()   # 레이어별 파라미터 수 출력
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ stock_input         │ (None, 90, 50)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ econ_input          │ (None, 90, 37)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ stock_input[0][0… │
# │ (MultiHeadAttentio… │                   │            │ stock_input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ econ_input[0][0], │
# │ (MultiHeadAttentio… │                   │            │ econ_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 90, 50)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 90, 50)    │          0 │ stock_input[0][0… │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 90, 37)    │          0 │ econ_input[0][0], │
# │                     │                   │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 90, 50)    │        100 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 90, 50)    │     12,850 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 90, 50)    │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 90, 37)    │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 90, 50)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 90, 50)    │     12,850 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 90, 50)    │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 90, 37)    │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 90, 50)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 90, 50)    │     12,850 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 90, 50)    │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 90, 37)    │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 90, 50)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 90, 50)    │     12,850 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 90, 50)    │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 90, 37)    │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 90, 64)    │      3,264 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 90, 64)    │      2,432 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 90, 64)    │          0 │ dense_8[0][0],    │
# │                     │                   │            │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 90, 128)   │      8,320 │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 90, 128)   │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dropout_24[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 50)        │      6,450 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 706,362 (2.69 MB)
#  Trainable params: 706,362 (2.69 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

CKPT_PATH = os.path.join(MODEL_DIR, "best_checkpoint.keras")

model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])

print(f"학습 시작 (epochs={EPOCHS}, batch_size={BATCH_SIZE}, 전체 데이터 학습)...")
history = model.fit(
    [X_stock_train, X_econ_train],
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[
        ModelCheckpoint(CKPT_PATH, monitor='loss', save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor='loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1),
    ],
    verbose=1
)
print(f"학습 완료 (실제 학습 에포크: {len(history.history['loss'])})")
# Out:
# 학습 시작 (epochs=50, batch_size=32, 전체 데이터 학습)...
# Epoch 1/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0949 - mae: 0.2018
# Epoch 1: loss improved from None to 0.03748, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 84s 145ms/step - loss: 0.0375 - mae: 0.1192 - learning_rate: 1.0000e-04
# Epoch 2/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0060 - mae: 0.0544
# Epoch 2: loss improved from 0.03748 to 0.00548, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0055 - mae: 0.0517 - learning_rate: 1.0000e-04
# Epoch 3/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0043 - mae: 0.0453
# Epoch 3: loss improved from 0.00548 to 0.00403, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - loss: 0.0040 - mae: 0.0442 - learning_rate: 1.0000e-04
# Epoch 4/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0034 - mae: 0.0407
# Epoch 4: loss improved from 0.00403 to 0.00325, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 0.0032 - mae: 0.0397 - learning_rate: 1.0000e-04
# Epoch 5/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0028 - mae: 0.0372
# Epoch 5: loss improved from 0.00325 to 0.00271, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0027 - mae: 0.0365 - learning_rate: 1.0000e-04
# Epoch 6/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0025 - mae: 0.0349
# Epoch 6: loss improved from 0.00271 to 0.00239, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0024 - mae: 0.0341 - learning_rate: 1.0000e-04
# Epoch 7/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0022 - mae: 0.0327
# Epoch 7: loss improved from 0.00239 to 0.00215, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0022 - mae: 0.0324 - learning_rate: 1.0000e-04
# Epoch 8/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0020 - mae: 0.0311
# Epoch 8: loss improved from 0.00215 to 0.00198, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - loss: 0.0020 - mae: 0.0309 - learning_rate: 1.0000e-04
# Epoch 9/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0018 - mae: 0.0298
# Epoch 9: loss improved from 0.00198 to 0.00184, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0018 - mae: 0.0298 - learning_rate: 1.0000e-04
# Epoch 10/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0018 - mae: 0.0292
# Epoch 10: loss improved from 0.00184 to 0.00173, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 0.0017 - mae: 0.0288 - learning_rate: 1.0000e-04
# Epoch 11/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0017 - mae: 0.0280
# Epoch 11: loss improved from 0.00173 to 0.00164, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0016 - mae: 0.0279 - learning_rate: 1.0000e-04
# Epoch 12/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0016 - mae: 0.0278
# Epoch 12: loss improved from 0.00164 to 0.00157, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0016 - mae: 0.0272 - learning_rate: 1.0000e-04
# Epoch 13/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0015 - mae: 0.0263
# Epoch 13: loss improved from 0.00157 to 0.00147, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0015 - mae: 0.0263 - learning_rate: 1.0000e-04
# Epoch 14/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0014 - mae: 0.0257
# Epoch 14: loss improved from 0.00147 to 0.00141, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0014 - mae: 0.0257 - learning_rate: 1.0000e-04
# Epoch 15/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - mae: 0.0251
# Epoch 15: loss improved from 0.00141 to 0.00134, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0013 - mae: 0.0250 - learning_rate: 1.0000e-04
# Epoch 16/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0246
# Epoch 16: loss improved from 0.00134 to 0.00130, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0013 - mae: 0.0245 - learning_rate: 1.0000e-04
# Epoch 17/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0241
# Epoch 17: loss improved from 0.00130 to 0.00122, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0012 - mae: 0.0238 - learning_rate: 1.0000e-04
# Epoch 18/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - mae: 0.0238
# Epoch 18: loss improved from 0.00122 to 0.00121, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0012 - mae: 0.0236 - learning_rate: 1.0000e-04
# Epoch 19/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0229
# Epoch 19: loss improved from 0.00121 to 0.00114, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0011 - mae: 0.0228 - learning_rate: 1.0000e-04
# Epoch 20/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - mae: 0.0223
# Epoch 20: loss improved from 0.00114 to 0.00110, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 20: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0011 - mae: 0.0224 - learning_rate: 1.0000e-04
# Epoch 21/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mae: 0.0220
# Epoch 21: loss improved from 0.00110 to 0.00105, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 21: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0011 - mae: 0.0219 - learning_rate: 1.0000e-04
# Epoch 22/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - mae: 0.0217
# Epoch 22: loss improved from 0.00105 to 0.00104, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 22: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0010 - mae: 0.0217 - learning_rate: 1.0000e-04
# Epoch 23/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0010 - mae: 0.0217
# Epoch 23: loss improved from 0.00104 to 0.00099, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 9.9015e-04 - mae: 0.0212 - learning_rate: 1.0000e-04
# Epoch 24/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.6833e-04 - mae: 0.0209
# Epoch 24: loss improved from 0.00099 to 0.00096, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 24: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.6048e-04 - mae: 0.0208 - learning_rate: 1.0000e-04
# Epoch 25/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.1003e-04 - mae: 0.0202
# Epoch 25: loss improved from 0.00096 to 0.00093, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 25: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 9.3162e-04 - mae: 0.0204 - learning_rate: 1.0000e-04
# Epoch 26/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.1616e-04 - mae: 0.0203
# Epoch 26: loss improved from 0.00093 to 0.00091, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 26: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 9.0941e-04 - mae: 0.0202 - learning_rate: 1.0000e-04
# Epoch 27/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.2106e-04 - mae: 0.0192
# Epoch 27: loss improved from 0.00091 to 0.00082, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 27: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 8.2257e-04 - mae: 0.0192 - learning_rate: 5.0000e-05
# Epoch 28/50
# 228/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.0798e-04 - mae: 0.0190
# Epoch 28: loss improved from 0.00082 to 0.00081, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 28: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 8.1494e-04 - mae: 0.0191 - learning_rate: 5.0000e-05
# Epoch 29/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.9943e-04 - mae: 0.0189
# Epoch 29: loss improved from 0.00081 to 0.00080, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 7.9811e-04 - mae: 0.0189 - learning_rate: 5.0000e-05
# Epoch 30/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.0284e-04 - mae: 0.0190
# Epoch 30: loss improved from 0.00080 to 0.00079, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 30: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 7.9350e-04 - mae: 0.0188 - learning_rate: 5.0000e-05
# Epoch 31/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.5236e-04 - mae: 0.0184
# Epoch 31: loss improved from 0.00079 to 0.00075, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 31: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 7.5270e-04 - mae: 0.0184 - learning_rate: 2.5000e-05
# Epoch 32/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.4873e-04 - mae: 0.0183
# Epoch 32: loss improved from 0.00075 to 0.00074, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 32: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 7.4393e-04 - mae: 0.0183 - learning_rate: 2.5000e-05
# Epoch 33/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.3748e-04 - mae: 0.0181
# Epoch 33: loss did not improve from 0.00074
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 7.4397e-04 - mae: 0.0182 - learning_rate: 2.5000e-05
# Epoch 34/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.2056e-04 - mae: 0.0180
# Epoch 34: loss improved from 0.00074 to 0.00072, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 34: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 7.2072e-04 - mae: 0.0180 - learning_rate: 1.2500e-05
# Epoch 35/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.1294e-04 - mae: 0.0179
# Epoch 35: loss improved from 0.00072 to 0.00072, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 7.1726e-04 - mae: 0.0179 - learning_rate: 1.2500e-05
# Epoch 36/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.1702e-04 - mae: 0.0179
# Epoch 36: loss improved from 0.00072 to 0.00071, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 36: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 7.1111e-04 - mae: 0.0179 - learning_rate: 1.2500e-05
# Epoch 37/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.0967e-04 - mae: 0.0179
# Epoch 37: loss improved from 0.00071 to 0.00071, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 37: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 7.0817e-04 - mae: 0.0178 - learning_rate: 1.2500e-05
# Epoch 38/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.0763e-04 - mae: 0.0178
# Epoch 38: loss improved from 0.00071 to 0.00070, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 38: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.9886e-04 - mae: 0.0177 - learning_rate: 6.2500e-06
# Epoch 39/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.0706e-04 - mae: 0.0178
# Epoch 39: loss did not improve from 0.00070
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 7.0011e-04 - mae: 0.0177 - learning_rate: 6.2500e-06
# Epoch 40/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.0210e-04 - mae: 0.0178
# Epoch 40: loss did not improve from 0.00070
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 7.0113e-04 - mae: 0.0177 - learning_rate: 6.2500e-06
# Epoch 41/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.8394e-04 - mae: 0.0175
# Epoch 41: loss improved from 0.00070 to 0.00069, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 41: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 6.8885e-04 - mae: 0.0176 - learning_rate: 3.1250e-06
# Epoch 42/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.8533e-04 - mae: 0.0175
# Epoch 42: loss improved from 0.00069 to 0.00069, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 42: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.8776e-04 - mae: 0.0175 - learning_rate: 3.1250e-06
# Epoch 43/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 6.7707e-04 - mae: 0.0175
# Epoch 43: loss improved from 0.00069 to 0.00069, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 43: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 6.8645e-04 - mae: 0.0175 - learning_rate: 3.1250e-06
# Epoch 44/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.9458e-04 - mae: 0.0176
# Epoch 44: loss did not improve from 0.00069
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 6.8817e-04 - mae: 0.0176 - learning_rate: 1.5625e-06
# Epoch 45/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.6770e-04 - mae: 0.0173
# Epoch 45: loss improved from 0.00069 to 0.00068, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 45: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - loss: 6.8370e-04 - mae: 0.0175 - learning_rate: 1.5625e-06
# Epoch 46/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.7395e-04 - mae: 0.0174
# Epoch 46: loss did not improve from 0.00068
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-06.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.8729e-04 - mae: 0.0175 - learning_rate: 1.5625e-06
# Epoch 47/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.8287e-04 - mae: 0.0175
# Epoch 47: loss did not improve from 0.00068
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 6.8378e-04 - mae: 0.0175 - learning_rate: 1.0000e-06
# Epoch 48/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.8302e-04 - mae: 0.0175
# Epoch 48: loss improved from 0.00068 to 0.00068, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 48: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 6.8099e-04 - mae: 0.0175 - learning_rate: 1.0000e-06
# Epoch 49/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.8125e-04 - mae: 0.0175
# Epoch 49: loss did not improve from 0.00068
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 6.8443e-04 - mae: 0.0175 - learning_rate: 1.0000e-06
# Epoch 50/50
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.7050e-04 - mae: 0.0174
# Epoch 50: loss improved from 0.00068 to 0.00068, saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
#
# Epoch 50: finished saving model to /content/drive/MyDrive/trader-ai/model/v2_260505/best_checkpoint.keras
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 6.8060e-04 - mae: 0.0175 - learning_rate: 1.0000e-06
# 학습 완료 (실제 학습 에포크: 50)

# %% [markdown]
# ## 7. 모델 저장 (스케일러 포함)

# %%
import json

# 저장 파일 경로 정의
MODEL_PATH        = os.path.join(MODEL_DIR, "transformer_stock.keras")  # 학습된 모델
STOCK_SCALER_PATH = os.path.join(MODEL_DIR, "stock_scaler.pkl")          # 주가 스케일러
ECON_SCALER_PATH  = os.path.join(MODEL_DIR, "econ_scaler.pkl")           # 경제지표 스케일러
META_PATH         = os.path.join(MODEL_DIR, "model_meta.json")           # 메타정보

# 모델과 스케일러를 저장합니다
# 스케일러는 나중에 예측값을 원래 가격 단위로 복원(inverse_transform)할 때 반드시 필요합니다
model.save(MODEL_PATH)
joblib.dump(stock_scaler, STOCK_SCALER_PATH)
joblib.dump(econ_scaler,  ECON_SCALER_PATH)

# 메타 정보 저장: 모델을 나중에 불러와 사용할 때 필요한 설정값들
# (어떤 컬럼을 입력으로 썼는지, lookback이 얼마인지 등)
meta = {
    "target_columns"    : TARGET_COLUMNS,
    "economic_features" : ECONOMIC_FEATURES,
    "lookback"          : LOOKBACK,
    "forecast_horizon"  : FORECAST_HORIZON,
    "test_mode"         : TEST_MODE,
}
with open(META_PATH, "w", encoding="utf-8") as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

print(f"모델 저장     : {MODEL_PATH}")
print(f"스케일러 저장 : {STOCK_SCALER_PATH}, {ECON_SCALER_PATH}")
print(f"메타 저장     : {META_PATH}")
print(f"모델 용량 : {MODEL_PATH} ({os.path.getsize(MODEL_PATH) / 1024**2:.2f} MB)")
# Out:
# 모델 저장     : /content/drive/MyDrive/trader-ai/model/v2_260505/transformer_stock.keras
# 스케일러 저장 : /content/drive/MyDrive/trader-ai/model/v2_260505/stock_scaler.pkl, /content/drive/MyDrive/trader-ai/model/v2_260505/econ_scaler.pkl
# 메타 저장     : /content/drive/MyDrive/trader-ai/model/v2_260505/model_meta.json
# 모델 용량 : /content/drive/MyDrive/trader-ai/model/v2_260505/transformer_stock.keras (8.54 MB)

# %% [markdown]
# ## 8. 예측 수행 및 DB 저장

# %%
# 전체 구간에 대해 예측을 수행합니다
# preds_scaled: 0~1 정규화된 예측값
# preds       : inverse_transform으로 실제 가격 단위로 복원

preds_scaled = model.predict([X_stock_full, X_econ_full], verbose=1)
preds        = stock_scaler.inverse_transform(preds_scaled)

# 예측값과 실제값을 날짜 기준으로 매핑합니다
# - dates : X_stock_full의 각 윈도우가 시작하는 날짜 (LOOKBACK 이후부터)
# - actual: 해당 날짜의 실제 주가 (비교용)
pred_len   = len(preds)
dates      = data['날짜'].iloc[LOOKBACK:LOOKBACK+pred_len].values
actual_end = min(LOOKBACK+pred_len, len(data))
actual     = data[TARGET_COLUMNS].iloc[LOOKBACK:actual_end].values

# 실제값 길이가 예측값보다 짧으면 NaN으로 패딩 (마지막 FORECAST_HORIZON행 구간)
if actual.shape[0] < pred_len:
    pad    = np.full((pred_len - actual.shape[0], len(TARGET_COLUMNS)), np.nan)
    actual = np.vstack([actual, pad])

# 결과 DataFrame 생성: 날짜별로 종목_Predicted / 종목_Actual 컬럼 쌍으로 구성
result_data = pd.DataFrame({'날짜': dates})
for idx, col in enumerate(TARGET_COLUMNS):
    result_data[f'{col}_Predicted'] = preds[:, idx]
    result_data[f'{col}_Actual']    = actual[:, idx]
result_data['날짜'] = pd.to_datetime(result_data['날짜']).dt.strftime('%Y-%m-%d')

print(f"예측 결과: {len(result_data)}행")
result_data.head(3)
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step
# 예측 결과: 7339행
# /tmp/ipykernel_842/1749695016.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_data[f'{col}_Actual']    = actual[:, idx]
#            날짜  엔비디아_Predicted  엔비디아_Actual  구글 A_Predicted  구글 A_Actual  \
# 0  2006-04-01       -2.404230     0.477167       -1.046584     9.759760
# 1  2006-04-02       -2.417536     0.477167       -1.048831     9.759760
# 2  2006-04-03       -2.431080     0.482500       -1.051428     9.752252
#
#    애플_Predicted  애플_Actual  마이크로소프트_Predicted  마이크로소프트_Actual  아마존_Predicted  \
# 0      4.032996     2.2400           2.568341       27.209999      -1.423518
# 1      4.027647     2.2400           2.613865       27.209999      -1.441824
# 2      4.022158     2.2375           2.659531       27.559999      -1.460097
#
#    ...  메리어트_Predicted  메리어트_Actual  메르카도리브레_Predicted  메르카도리브레_Actual  \
# 0  ...       30.334776    31.974987         -21.590696            28.5
# 1  ...       30.362267    31.974987         -21.570915            28.5
# 2  ...       30.390270    32.627537         -21.555416            28.5
#
#    ADP_Predicted  ADP_Actual  에어비앤비_Predicted  에어비앤비_Actual  몬델리즈_Predicted  \
# 0      31.841293   36.227169       149.755264    144.710007       26.052858
# 1      31.861868   36.227169       149.795853    144.710007       26.071062
# 2      31.882139   36.591976       149.836334    144.710007       26.089279
#
#    몬델리즈_Actual
# 0    30.309999
# 1    30.309999
# 2    30.280001
#
# [3 rows x 101 columns]

# %%
def save_predictions_to_db(df, chunk_size=100):
    """
    예측 결과를 Supabase의 predicted_stocks 테이블에 저장합니다.

    저장 전 기존 데이터를 전부 삭제하고 새 데이터로 교체합니다.
    (항상 최신 예측 결과만 유지)

    NaN/Inf 값은 DB에 저장 불가하므로 None으로 변환합니다.
    chunk_size 단위로 나눠서 insert (한 번에 너무 많으면 API 오류 방지)
    """
    import math
    records = []
    for _, row in df.iterrows():
        rec = {}
        for k, v in row.items():
            if isinstance(v, float) and (math.isnan(v) or math.isinf(v)):
                rec[k] = None   # NaN/Inf → None (DB에 NULL로 저장)
            else:
                rec[k] = v
        records.append(rec)

    # 기존 데이터 전체 삭제 후 새 데이터 삽입
    supabase_admin.table("predicted_stocks").delete().neq("id", 0).execute()
    for i in range(0, len(records), chunk_size):
        supabase_admin.table("predicted_stocks").insert(records[i:i+chunk_size]).execute()
    print(f"{len(records)}개 예측 결과 저장 완료")


save_predictions_to_db(result_data)
# Out:
# 7339개 예측 결과 저장 완료

# %% [markdown]
# ## 9. 학습 시각화

# %%
plt.figure(figsize=(10, 4))
plt.plot(history.history['loss'], label='Train Loss')
plt.title('Training Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 10. 결과 분석 (저장된 모델 로드 후 평가)
#
# > 학습 없이 이 섹션부터 실행 가능 — 저장된 모델을 불러와서 분석

# %%
# 이 셀부터는 학습 없이 저장된 모델을 불러와서 분석만 수행합니다
# 이미 학습이 완료된 상태라면 위 학습 셀들을 건너뛰고 여기서부터 실행 가능합니다

loaded_model        = load_model(MODEL_PATH)
loaded_stock_scaler = joblib.load(STOCK_SCALER_PATH)
loaded_econ_scaler  = joblib.load(ECON_SCALER_PATH)

# 메타 정보 로드: 모델이 어떤 컬럼/설정으로 학습되었는지 확인
with open(META_PATH, encoding='utf-8') as f:
    meta = json.load(f)

print(f"모델 로드 완료: {MODEL_PATH}")
print(f"메타 정보: lookback={meta['lookback']}, forecast_horizon={meta['forecast_horizon']}")
print(f"종목 수: {len(meta['target_columns'])}개")
# Out:
# 모델 로드 완료: /content/drive/MyDrive/trader-ai/model/v2_260505/transformer_stock.keras
# 메타 정보: lookback=90, forecast_horizon=14
# 종목 수: 50개

# %%
def load_predictions_from_db(chunk_size=1000):
    """
    predicted_stocks 테이블에서 저장된 예측 결과를 로드합니다.
    Supabase 페이지 제한(1000행)을 고려해 offset을 이동하며 전체를 가져옵니다.
    """
    # 전체 행 수를 먼저 조회해서 반복 횟수 결정
    count_resp  = supabase.table("predicted_stocks").select("id", count="exact").execute()
    total_count = count_resp.count
    all_data    = []
    for offset in range(0, total_count, chunk_size):
        resp = (
            supabase.table("predicted_stocks")
            .select("*")
            .order("날짜", desc=False)
            .limit(chunk_size)
            .offset(offset)
            .execute()
        )
        all_data.extend(resp.data)
    df = pd.DataFrame(all_data)
    df['날짜'] = pd.to_datetime(df['날짜'])
    return df


pred_df = load_predictions_from_db()
print(f"예측 데이터 로드: {len(pred_df)}행")
pred_df.head(3)
# Out:
# 예측 데이터 로드: 7339행
#       id         날짜  엔비디아_Predicted  엔비디아_Actual  구글 A_Predicted  구글 A_Actual  \
# 0  14679 2006-04-01       -2.404230     0.477167       -1.046584     9.759760
# 1  14680 2006-04-02       -2.417536     0.477167       -1.048831     9.759760
# 2  14681 2006-04-03       -2.431080     0.482500       -1.051428     9.752252
#
#    애플_Predicted  애플_Actual  마이크로소프트_Predicted  마이크로소프트_Actual  ...  \
# 0      4.032996     2.2400           2.568341       27.209999  ...
# 1      4.027647     2.2400           2.613865       27.209999  ...
# 2      4.022158     2.2375           2.659531       27.559999  ...
#
#    메리어트_Actual  메르카도리브레_Predicted  메르카도리브레_Actual  ADP_Predicted  ADP_Actual  \
# 0    31.974987         -21.590696            28.5      31.841293   36.227169
# 1    31.974987         -21.570915            28.5      31.861868   36.227169
# 2    32.627537         -21.555416            28.5      31.882139   36.591976
#
#    에어비앤비_Predicted  에어비앤비_Actual  몬델리즈_Predicted  몬델리즈_Actual  \
# 0       149.755264    144.710007       26.052858    30.309999
# 1       149.795853    144.710007       26.071062    30.309999
# 2       149.836334    144.710007       26.089279    30.280001
#
#                         created_at
# 0  2026-05-05T10:15:02.06091+00:00
# 1  2026-05-05T10:15:02.06091+00:00
# 2  2026-05-05T10:15:02.06091+00:00
#
# [3 rows x 103 columns]

# %%
def evaluate_predictions(df, target_cols, horizon):
    """
    예측 정확도를 계산합니다.

    지표 설명:
      MAE       : 평균 절대 오차 (작을수록 좋음)
      RMSE      : 평균 제곱근 오차 (이상치에 민감, 작을수록 좋음)
      MAPE (%)  : 평균 절대 비율 오차 (실제값 대비 몇 % 틀렸는지)
      Accuracy  : 100 - MAPE (높을수록 좋음)

    주의: 예측값은 horizon일 뒤 주가이므로, 실제값도 horizon만큼 shift해서 비교합니다.
    TEST_MODE에서는 데이터가 부족해 비교 불가(Empty)가 정상입니다.
    """
    metrics = []
    for col in target_cols:
        pred_col   = f'{col}_Predicted'
        actual_col = f'{col}_Actual'
        if pred_col not in df.columns or actual_col not in df.columns:
            continue
        predicted = pd.to_numeric(df[pred_col], errors='coerce')
        actual    = pd.to_numeric(df[actual_col], errors='coerce').shift(-horizon)
        mask      = ~predicted.isna() & ~actual.isna()
        predicted, actual = predicted[mask], actual[mask]
        if len(predicted) == 0:
            continue
        mae  = mean_absolute_error(actual, predicted)
        rmse = mean_squared_error(actual, predicted) ** 0.5
        mape = (abs((actual - predicted) / actual).mean()) * 100
        metrics.append({
            'Stock'       : col,
            'MAE'         : round(mae, 4),
            'RMSE'        : round(rmse, 4),
            'MAPE (%)'    : round(mape, 2),
            'Accuracy (%)': round(100 - mape, 2)
        })
    result = pd.DataFrame(metrics)
    if result.empty:
        print("평가 데이터 부족 (테스트 모드에서는 정상)")
        return result
    return result.sort_values('Accuracy (%)', ascending=False)


eval_df = evaluate_predictions(pred_df, meta['target_columns'], meta['forecast_horizon'])
print("=== 성능 평가 ===")
eval_df
# Out:
# === 성능 평가 ===
#           Stock      MAE     RMSE  MAPE (%)  Accuracy (%)
# 48        에어비앤비   3.9878   5.4374      2.84         97.16
# 23          펩시코   5.4488   6.4552      6.14         93.86
# 49         몬델리즈   2.5056   3.1232      6.16         93.84
# 27           퀄컴   5.1012   6.6107      7.02         92.98
# 22          Arm   5.3365   7.5718      7.26         92.74
# 20           린드  11.9993  15.7200      7.61         92.39
# 15          시스코   2.3810   2.8984      7.91         92.09
# 35    허니웰 인터내셔널   6.5814   8.1914      8.36         91.64
# 8           월마트   2.5555   3.3148      8.37         91.63
# 28           암젠  12.3102  15.1871      8.84         91.16
# 42         컴캐스트   1.8084   2.1493      9.24         90.76
# 12           인텔   3.0097   3.7229      9.74         90.26
# 47          ADP   8.3677  10.0651     10.33         89.67
# 44         시놉시스  13.0431  21.3917     12.68         87.32
# 38   콘스텔레이션 에너지   8.5533  13.1225     13.26         86.74
# 37         스타벅스   4.2868   5.0713     13.42         86.58
# 39         인튜이트  16.8655  24.6223     13.52         86.48
# 45         메리어트  10.2509  13.2332     13.58         86.42
# 25     아나로그디바이스   9.1922  11.5657     14.56         85.44
# 13         코스트코  28.7883  37.6657     14.59         85.41
# 34     마벨 테크놀로지   3.5656   4.6413     15.71         84.29
# 31    인튜이티브 서지컬  16.2469  23.1993     16.81         83.19
# 19   텍사스 인스트루먼트   9.5821  11.0635     17.97         82.03
# 33    팔로알토 네트웍스   5.7926   8.0493     19.20         80.80
# 6            메타  19.2613  24.8420     20.04         79.96
# 32          앱러빈  12.8132  19.4417     21.36         78.64
# 1          구글 A   7.0878   9.6865     21.40         78.60
# 3       마이크로소프트  13.9007  17.1004     23.47         76.53
# 24         티모바일   9.8902  11.9424     24.00         76.00
# 40   버텍스 파마슈티컬스  20.8406  24.9088     24.84         75.16
# 36        부킹홀딩스   5.3165   7.0544     26.20         73.80
# 41          어도비  20.6470  24.8664     26.56         73.44
# 18  어플라이드 머티리얼즈   8.1596  11.4626     26.83         73.17
# 2            애플   6.5971   8.5685     28.38         71.62
# 4           아마존   6.5821   8.5825     30.98         69.02
# 43         케이던스   8.2111  11.4212     32.19         67.81
# 11         ASML  37.5599  46.5712     32.92         67.08
# 46      메르카도리브레  65.5180  93.5171     34.21         65.79
# 16         팔란티어   4.4101   5.9882     34.44         65.56
# 30         씨게이트  16.2257  21.4877     43.22         56.78
# 17         램리서치   4.9527   6.9893     49.76         50.24
# 9          마이크론  10.0103  13.0060     55.92         44.08
# 10          AMD   7.1876  11.4342     58.40         41.60
# 26         샌디스크  23.2746  30.1288     60.36         39.64
# 21     KLA Corp  51.2969  59.2522     68.37         31.63
# 29         쇼피파이   5.2765   6.8671    135.05        -35.05
# 5          브로드컴   8.4482  11.0245    140.82        -40.82
# 7           테슬라  14.1885  20.1637    187.17        -87.17
# 14         넷플릭스   5.0839   5.8792    275.99       -175.99
# 0          엔비디아   4.5422   6.3586    354.80       -254.80

# %%
def analyze_rise(df, target_cols):
    """
    가장 최근 행 기준으로 각 종목의 상승/하락 여부와 등락률을 계산합니다.

    - Last Actual  : 가장 최근 실제 주가
    - Predicted    : 모델이 예측한 FORECAST_HORIZON일 뒤 주가
    - Rise         : 예측가 > 실제가 이면 True (상승 예측)
    - Rise Prob(%) : (예측가 - 실제가) / 실제가 × 100 (예상 등락률)

    트레이딩 앱에서 이 값을 참고해 매수 종목을 결정합니다.
    """
    last    = df.iloc[-1]   # 가장 최근 날짜 행
    results = []
    for col in target_cols:
        last_actual = last.get(f'{col}_Actual', np.nan)
        pred_future = last.get(f'{col}_Predicted', np.nan)
        if pd.notna(last_actual) and pd.notna(pred_future):
            rise = pred_future > last_actual
            prob = ((pred_future - last_actual) / last_actual) * 100
        else:
            rise, prob = np.nan, np.nan
        results.append({
            'Stock'        : col,
            'Last Actual'  : round(last_actual, 2) if pd.notna(last_actual) else np.nan,
            'Predicted'    : round(pred_future, 2) if pd.notna(pred_future) else np.nan,
            'Rise'         : rise,
            'Rise Prob (%)': round(prob, 2) if pd.notna(prob) else np.nan
        })
    return pd.DataFrame(results).sort_values('Rise Prob (%)', ascending=False)


rise_df = analyze_rise(pred_df, meta['target_columns'])
print("=== 상승/하락 예측 ===")
rise_df
# Out:
# === 상승/하락 예측 ===
#           Stock  Last Actual  Predicted   Rise  Rise Prob (%)
# 22          Arm       203.26     277.16   True          36.36
# 29         쇼피파이       127.55     168.33   True          31.97
# 41          어도비       253.96     327.21   True          28.84
# 21     KLA Corp      1713.32    2186.43   True          27.61
# 38   콘스텔레이션 에너지       321.05     396.37   True          23.46
# 5          브로드컴       416.50     511.85   True          22.89
# 18  어플라이드 머티리얼즈       391.38     478.69   True          22.31
# 17         램리서치       258.57     315.96   True          22.19
# 45         메리어트       347.24     423.59   True          21.99
# 34     마벨 테크놀로지       163.66     198.98   True          21.58
# 19   텍사스 인스트루먼트       280.89     338.56   True          20.53
# 3       마이크로소프트       413.62     497.84   True          20.36
# 14         넷플릭스        91.02     109.27   True          20.05
# 32          앱러빈       475.00     568.01   True          19.58
# 36        부킹홀딩스       165.58     197.98   True          19.57
# 4           아마존       272.05     323.92   True          19.07
# 13         코스트코      1012.79    1201.48   True          18.63
# 40   버텍스 파마슈티컬스       429.85     509.15   True          18.45
# 10          AMD       341.54     400.94   True          17.39
# 25     아나로그디바이스       397.02     464.96   True          17.11
# 15          시스코        92.63     107.78   True          16.35
# 2            애플       276.83     321.54   True          16.15
# 7           테슬라       392.51     455.22   True          15.98
# 0          엔비디아       198.48     229.80   True          15.78
# 20           린드       493.55     570.80   True          15.65
# 30         씨게이트       738.54     835.94   True          13.19
# 11         ASML      1386.21    1565.52   True          12.94
# 49         몬델리즈        61.38      68.88   True          12.23
# 35    허니웰 인터내셔널       209.59     234.09   True          11.69
# 37         스타벅스       104.97     116.82   True          11.28
# 6            메타       610.41     675.54   True          10.67
# 48        에어비앤비       138.86     153.59   True          10.61
# 26         샌디스크      1255.86    1387.56   True          10.49
# 33    팔로알토 네트웍스       184.56     203.86   True          10.46
# 8           월마트       130.33     143.62   True          10.20
# 23          펩시코       154.59     169.69   True           9.77
# 39         인튜이트       406.99     439.76   True           8.05
# 24         티모바일       194.42     207.15   True           6.55
# 46      메르카도리브레      1813.53    1916.59   True           5.68
# 42         컴캐스트        27.07      28.52   True           5.37
# 27           퀄컴       168.38     176.97   True           5.10
# 43         케이던스       349.51     361.16   True           3.33
# 28           암젠       323.85     332.47   True           2.66
# 47          ADP       211.32     216.90   True           2.64
# 12           인텔        95.78      98.14   True           2.47
# 31    인튜이티브 서지컬       452.35     458.67   True           1.40
# 16         팔란티어       146.03     147.45   True           0.97
# 9          마이크론       576.45     557.76  False          -3.24
# 44         시놉시스       497.50     465.94  False          -6.34
# 1          구글 A       383.25     353.84  False          -7.67

# %%
def get_recommendation(row):
    """
    상승 확률에 따라 매수/매도 추천 등급을 반환합니다.
      STRONG BUY : 상승 예측 + 등락률 2% 초과
      BUY        : 상승 예측 + 등락률 0~2%
      SELL       : 하락 예측 또는 데이터 없음
    """
    prob = row.get('Rise Prob (%)', 0)
    rise = row.get('Rise', False)
    if pd.isna(prob) or pd.isna(rise):
        return "No Data"
    if rise and prob > 2:
        return "STRONG BUY"
    elif rise and prob > 0:
        return "BUY"
    return "SELL"


# 성능 평가(eval_df)와 상승분석(rise_df)을 종목 기준으로 합칩니다
if eval_df.empty or rise_df.empty:
    final = rise_df.copy() if not rise_df.empty else eval_df.copy()
else:
    final = pd.merge(eval_df, rise_df, on='Stock', how='outer')

final['Recommendation'] = final.apply(get_recommendation, axis=1)
final = final.sort_values('Rise Prob (%)', ascending=False) if 'Rise Prob (%)' in final.columns else final

print("=== 최종 리포트 ===")
show_cols = [c for c in ['Stock', 'Accuracy (%)', 'Rise Prob (%)', 'Recommendation'] if c in final.columns]
final[show_cols]
# Out:
# === 최종 리포트 ===
#           Stock  Accuracy (%)  Rise Prob (%) Recommendation
# 3           Arm         92.74          36.36     STRONG BUY
# 20         쇼피파이        -35.05          31.97     STRONG BUY
# 30          어도비         73.44          28.84     STRONG BUY
# 4      KLA Corp         31.63          27.61     STRONG BUY
# 41   콘스텔레이션 에너지         86.74          23.46     STRONG BUY
# 18         브로드컴        -40.82          22.89     STRONG BUY
# 31  어플라이드 머티리얼즈         73.17          22.31     STRONG BUY
# 7          램리서치         50.24          22.19     STRONG BUY
# 13         메리어트         86.42          21.99     STRONG BUY
# 9      마벨 테크놀로지         84.29          21.58     STRONG BUY
# 44   텍사스 인스트루먼트         82.03          20.53     STRONG BUY
# 10      마이크로소프트         76.53          20.36     STRONG BUY
# 6          넷플릭스       -175.99          20.05     STRONG BUY
# 29          앱러빈         78.64          19.58     STRONG BUY
# 17        부킹홀딩스         73.80          19.57     STRONG BUY
# 26          아마존         69.02          19.07     STRONG BUY
# 40         코스트코         85.41          18.63     STRONG BUY
# 16   버텍스 파마슈티컬스         75.16          18.45     STRONG BUY
# 1           AMD         41.60          17.39     STRONG BUY
# 25     아나로그디바이스         85.44          17.11     STRONG BUY
# 23          시스코         92.09          16.35     STRONG BUY
# 28           애플         71.62          16.15     STRONG BUY
# 43          테슬라        -87.17          15.98     STRONG BUY
# 33         엔비디아       -254.80          15.78     STRONG BUY
# 8            린드         92.39          15.65     STRONG BUY
# 24         씨게이트         56.78          13.19     STRONG BUY
# 2          ASML         67.08          12.94     STRONG BUY
# 15         몬델리즈         93.84          12.23     STRONG BUY
# 49    허니웰 인터내셔널         91.64          11.69     STRONG BUY
# 21         스타벅스         86.58          11.28     STRONG BUY
# 14           메타         79.96          10.67     STRONG BUY
# 32        에어비앤비         97.16          10.61     STRONG BUY
# 19         샌디스크         39.64          10.49     STRONG BUY
# 47    팔로알토 네트웍스         80.80          10.46     STRONG BUY
# 34          월마트         91.63          10.20     STRONG BUY
# 48          펩시코         93.86           9.77     STRONG BUY
# 36         인튜이트         86.48           8.05     STRONG BUY
# 45         티모바일         76.00           6.55     STRONG BUY
# 12      메르카도리브레         65.79           5.68     STRONG BUY
# 38         컴캐스트         90.76           5.37     STRONG BUY
# 42           퀄컴         92.98           5.10     STRONG BUY
# 39         케이던스         67.81           3.33     STRONG BUY
# 27           암젠         91.16           2.66     STRONG BUY
# 0           ADP         89.67           2.64     STRONG BUY
# 35           인텔         90.26           2.47     STRONG BUY
# 37    인튜이티브 서지컬         83.19           1.40            BUY
# 46         팔란티어         65.56           0.97            BUY
# 11         마이크론         44.08          -3.24           SELL
# 22         시놉시스         87.32          -6.34           SELL
# 5          구글 A         78.60          -7.67           SELL

# %%
def save_analysis_to_db(df, chunk_size=100):
    """
    최종 분석 결과(추천 등급, 상승 확률 등)를 stock_analysis_results 테이블에 저장합니다.
    이 테이블이 트레이딩 앱의 매수 판단에 직접 사용됩니다.

    - 컬럼명을 DB 스키마에 맞게 rename 후 저장
    - NaN/Inf → None 변환 (DB NULL)
    - bool/numpy 타입 → Python 기본 타입 변환
    - 기존 데이터 전체 삭제 후 새 데이터로 교체
    """
    import math
    col_map = {
        'Stock'           : 'Stock',
        'MAE'             : 'MAE',
        'RMSE'            : 'RMSE',
        'MAPE (%)'        : 'MAPE (%)',
        'Accuracy (%)'    : 'Accuracy (%)',
        'Last Actual'     : 'Last Actual Price',
        'Predicted'       : 'Predicted Future Price',
        'Rise'            : 'Predicted Rise',
        'Rise Prob (%)'   : 'Rise Probability (%)',
        'Recommendation'  : 'Recommendation'
    }
    save_df = df.rename(columns=col_map)
    records = []
    for _, row in save_df.iterrows():
        rec = {}
        for k, v in row.items():
            if isinstance(v, float) and (math.isnan(v) or math.isinf(v)):
                rec[k] = None
            elif hasattr(v, 'item'):   # numpy 타입 → Python 기본 타입
                rec[k] = v.item()
            else:
                rec[k] = v
        records.append(rec)

    supabase_admin.table("stock_analysis_results").delete().neq("id", 0).execute()
    for i in range(0, len(records), chunk_size):
        supabase_admin.table("stock_analysis_results").insert(records[i:i+chunk_size]).execute()
    print(f"{len(records)}개 분석 결과 저장 완료")


save_analysis_to_db(final)
print("\n=== 모든 작업 완료 ===")
# Out:
# 50개 분석 결과 저장 완료
#
# === 모든 작업 완료 ===
