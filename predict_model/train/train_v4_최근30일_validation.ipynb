# %% [markdown]
# # 주가 예측 모델 (Transformer)
#
# ## ⚙️ 실행 전 설정
# - `TEST_MODE = True` → 로컬 소규모 테스트 (빠름)
# - `TEST_MODE = False` → Google Colab 실제 학습 (전체 데이터, GPU)
# - `IS_LOCAL = True` → 모델을 `model/` 로컬 경로에 저장
# - `IS_LOCAL = False` → Google Drive 경로에 저장

# %%
# ============================================================
# 실행 설정 변수 — 여기만 수정하면 됩니다
# ============================================================
#
# TEST_MODE:
#   True  → 최신 100행, epoch 2회로 빠르게 동작 확인용 (로컬 테스트)
#   False → 전체 데이터, epoch 50회로 실제 학습 (Google Colab 권장)
#
# IS_LOCAL:
#   True  → 로컬 ../model/ 경로에 모델 저장
#   False → Google Colab 환경에서 Google Drive 경로에 저장

TEST_MODE = False
IS_LOCAL  = False

# 로컬 저장 경로 (IS_LOCAL=True 일 때 사용)
LOCAL_MODEL_DIR = "../model"

# Google Drive 저장 경로 (IS_LOCAL=False, Colab 환경일 때 사용)
DRIVE_MODEL_DIR = "/content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation"
# 학습 업데이트 시 아래 추가 후, 돌림 (학습날짜 별로 모델 관리)
# DRIVE_MODEL_DIR = "/content/drive/MyDrive/trader-ai/model/v2_260505"

# 위 두 설정에 따라 실제 저장 경로 자동 결정
MODEL_DIR = LOCAL_MODEL_DIR if IS_LOCAL else DRIVE_MODEL_DIR

# ── 하이퍼파라미터 ──────────────────────────────────────────
# TEST_MODE에 따라 자동으로 값이 달라집니다
# LOOKBACK         : 모델이 과거 며칠치 데이터를 보고 예측할지
# FORECAST_HORIZON : 며칠 뒤 주가를 예측할지
# EPOCHS           : 학습 반복 횟수 (많을수록 정확하지만 오래 걸림)
# BATCH_SIZE       : 한 번에 학습할 데이터 샘플 수
if TEST_MODE:
    DATA_LIMIT       = 100   # 테스트용 소량 데이터 (최신 100행)
    LOOKBACK         = 20    # 과거 20일 데이터를 입력으로 사용
    FORECAST_HORIZON = 5     # 5일 뒤 주가 예측
    EPOCHS           = 2
    BATCH_SIZE       = 8
else:
    DATA_LIMIT       = None  # 전체 데이터 사용
    LOOKBACK         = 90    # 과거 90일(약 3개월)
    FORECAST_HORIZON = 14    # 2주 뒤 주가 예측
    EPOCHS           = 50
    BATCH_SIZE       = 32

print(f"TEST_MODE        : {TEST_MODE}")
print(f"IS_LOCAL         : {IS_LOCAL}")
print(f"MODEL_DIR        : {MODEL_DIR}")
print(f"DATA_LIMIT       : {DATA_LIMIT}")
print(f"LOOKBACK         : {LOOKBACK}")
print(f"FORECAST_HORIZON : {FORECAST_HORIZON}")
print(f"EPOCHS           : {EPOCHS}")
# Out:
# TEST_MODE        : False
# IS_LOCAL         : False
# MODEL_DIR        : /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation
# DATA_LIMIT       : None
# LOOKBACK         : 90
# FORECAST_HORIZON : 14
# EPOCHS           : 50

# %% [markdown]
# ## 1. 환경 설정

# %%
# Google Colab 환경(IS_LOCAL=False)일 때만 실행되는 초기화 블록
# - Google Drive를 마운트해서 모델 저장 경로를 사용할 수 있게 함
# - Colab 기본 환경에 없는 패키지(supabase, scikit-learn)를 설치
if not IS_LOCAL:
    from google.colab import drive
    drive.mount('/content/drive')
    import subprocess
    subprocess.run(['pip', 'install', 'supabase', 'scikit-learn'], check=True)

import os
# 모델을 저장할 디렉토리가 없으면 자동 생성
os.makedirs(MODEL_DIR, exist_ok=True)
print(f"모델 저장 경로 준비 완료: {MODEL_DIR}")
# Out:
# Mounted at /content/drive
# 모델 저장 경로 준비 완료: /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation

# %%
# ── 데이터 처리 ──────────────────────────────────────────────
import joblib          # 스케일러(.pkl) 저장/로드
import numpy as np
import pandas as pd

# ── 전처리 & 평가 지표 ──────────────────────────────────────
from sklearn.preprocessing import MinMaxScaler          # 0~1 정규화
from sklearn.metrics import mean_absolute_error, mean_squared_error

# ── DB 연결 ─────────────────────────────────────────────────
from supabase import create_client, Client   # Supabase(PostgreSQL) 클라이언트

# ── 딥러닝 모델 (Transformer) ────────────────────────────────
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, LayerNormalization,
    MultiHeadAttention,   # Transformer의 핵심 — 시퀀스 내 각 시점간 관계 학습
    Add, GlobalAveragePooling1D
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint  # 과적합 방지

# ── 시각화 ──────────────────────────────────────────────────
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

print(f"TensorFlow: {tf.__version__}")
print(f"GPU 사용 가능: {len(tf.config.list_physical_devices('GPU')) > 0}")
# Out:
# TensorFlow: 2.20.0
# GPU 사용 가능: True

# %% [markdown]
# ## 2. Supabase 연결

# %%
# Supabase는 이 프로젝트의 데이터베이스 역할을 합니다
# - 학습 원본 데이터(주가 + 경제지표)를 읽어옴
# - 예측 결과를 저장해서 트레이딩 앱이 읽어갈 수 있게 함
#
# service_role 키: RLS(Row Level Security)를 우회하여 읽기/쓰기 모두 가능
# 주의: 이 키는 외부에 노출되면 안 됩니다

SUPABASE_URL         = "https://cubyfztyjnyqbsiemhay.supabase.co"
SUPABASE_SERVICE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImN1YnlmenR5am55cWJzaWVtaGF5Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc3NzgwMTgxMiwiZXhwIjoyMDkzMzc3ODEyfQ.1I1StMUdPfRVsHDNaKPAUcR70AJVJ-_25pdjPS_O4J8"

supabase       = create_client(SUPABASE_URL, SUPABASE_SERVICE_KEY)
supabase_admin = supabase   # 읽기/쓰기 모두 같은 클라이언트 사용
print("Supabase 연결 완료 (service_role)")
# Out:
# Supabase 연결 완료 (service_role)

# %% [markdown]
# ## 3. 데이터 로드

# %%
def get_all_rows(table_name, limit_rows=None, chunk=1000, latest_first=False):
    """
    Supabase 테이블에서 전체 데이터를 페이지 단위로 가져옵니다.

    Args:
        table_name   : 조회할 테이블 이름
        limit_rows   : 최대 로드 행 수 (None이면 전체)
        chunk        : 한 번에 가져올 행 수
        latest_first : True이면 최신 데이터부터 가져옴 (TEST_MODE용)
    """
    # latest_first=True면 최신 데이터부터 가져와서 limit 이후 재정렬
    order_desc = latest_first and (limit_rows is not None)
    all_data, offset = [], 0
    while True:
        fetch = min(chunk, limit_rows - len(all_data)) if limit_rows else chunk
        resp = (
            supabase.table(table_name)
            .select("*")
            .order("날짜", desc=order_desc)
            .limit(fetch)
            .offset(offset)
            .execute()
        )
        if not resp.data:
            break
        all_data.extend(resp.data)
        if limit_rows and len(all_data) >= limit_rows:
            break
        offset += chunk
    return all_data


def load_data(limit_rows=None):
    """
    economic_and_stock_data 테이블에서 데이터를 로드하고 전처리합니다.

    전처리 순서:
      1. 날짜 파싱 및 오름차순 정렬
      2. ffill/bfill: 누락된 값을 앞뒤 값으로 채움 (주말/공휴일 등 결측치 처리)
      3. 숫자 변환: 문자열로 저장된 수치를 float으로 변환
      4. 100% NaN인 컬럼 제외 후 dropna
    """
    # limit_rows가 있으면 최신 데이터부터 가져옴 (2006년 오래된 데이터 방지)
    rows = get_all_rows("economic_and_stock_data", limit_rows=limit_rows, latest_first=(limit_rows is not None))
    df = pd.DataFrame(rows)
    df['날짜'] = pd.to_datetime(df['날짜'])
    df.sort_values('날짜', inplace=True)   # 최신 우선으로 가져왔으므로 다시 오름차순 정렬
    df = df.ffill().bfill()
    numeric_cols = [c for c in df.columns if c != '날짜']
    df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
    nan_ratios = df[numeric_cols].isna().mean()
    valid_cols = nan_ratios[nan_ratios < 1.0].index.tolist()
    df.dropna(subset=valid_cols, inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

# %%
# 위에서 정의한 함수로 실제 데이터를 불러옵니다
# TEST_MODE=True 이면 DATA_LIMIT=100 행만 로드 (최신 데이터 기준, 빠른 테스트용)
# TEST_MODE=False 이면 전체 기간 데이터 로드
print(f"데이터 로드 중... (limit={DATA_LIMIT})")
data = load_data(limit_rows=DATA_LIMIT)

print(f"로드 완료: {len(data):,}행 × {len(data.columns)}컬럼")
print(f"기간: {data['날짜'].min().date()} ~ {data['날짜'].max().date()}")
data.head(3)
# Out:
# 데이터 로드 중... (limit=None)
# 로드 완료: 7,429행 × 88컬럼
# 기간: 2006-01-01 ~ 2026-05-04
#           날짜  10년 기대 인플레이션율  장단기 금리차  기준금리  미시간대 소비자 심리지수  실업률  \
# 0 2006-01-01           2.34     0.03  4.29           91.2  4.7
# 1 2006-01-02           2.34     0.03  4.29           91.2  4.7
# 2 2006-01-03           2.34     0.03  4.29           91.2  4.7
#
#    2년 만기 미국 국채 수익률  10년 만기 미국 국채 수익률  금융스트레스지수  개인 소비 지출  ...  버텍스 파마슈티컬스  \
# 0             4.34              4.37   -0.8478    9071.6  ...        27.9
# 1             4.34              4.37   -0.8478    9071.6  ...        27.9
# 2             4.34              4.37   -0.8478    9071.6  ...        27.9
#
#      어도비      컴캐스트       케이던스       시놉시스      메리어트  메르카도리브레        ADP  \
# 0  38.52  8.194314  16.950001  20.459999  31.46693     28.5  36.742661
# 1  38.52  8.194314  16.950001  20.459999  31.46693     28.5  36.742661
# 2  38.52  8.194314  16.950001  20.459999  31.46693     28.5  36.742661
#
#         에어비앤비       몬델리즈
# 0  144.710007  28.049999
# 1  144.710007  28.049999
# 2  144.710007  28.049999
#
# [3 rows x 88 columns]

# %%
# 결측치
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (7429, 88)

# %% [markdown]
# ## 4. 피처 정의

# %%
# ── 예측 대상(Target) ─────────────────────────────────────────
# 나스닥 50개 종목 — 모델 출력(y)
TARGET_COLUMNS = [
    '엔비디아', '구글 A', '애플', '마이크로소프트', '아마존',
    '브로드컴', '메타', '테슬라', '월마트', '마이크론',
    'AMD', 'ASML', '인텔', '코스트코', '넷플릭스',
    '시스코', '팔란티어', '램리서치', '어플라이드 머티리얼즈', '텍사스 인스트루먼트',
    '린드', 'KLA Corp', 'Arm', '펩시코', '티모바일',
    '아나로그디바이스', '샌디스크', '퀄컴', '암젠', '쇼피파이',
    '씨게이트', '인튜이티브 서지컬', '앱러빈', '팔로알토 네트웍스', '마벨 테크놀로지',
    '허니웰 인터내셔널', '부킹홀딩스', '스타벅스', '콘스텔레이션 에너지', '인튜이트',
    '버텍스 파마슈티컬스', '어도비', '컴캐스트', '케이던스', '시놉시스',
    '메리어트', '메르카도리브레', 'ADP', '에어비앤비', '몬델리즈',
]

# ── 입력 피처(Feature) ────────────────────────────────────────
# 거시경제 지표 + 글로벌 지수/ETF/환율 — 모델 보조 입력(econ_input)
ECONOMIC_FEATURES = [
    '10년 기대 인플레이션율', '장단기 금리차', '기준금리', '미시간대 소비자 심리지수',
    '실업률', '2년 만기 미국 국채 수익률', '10년 만기 미국 국채 수익률', '금융스트레스지수',
    '개인 소비 지출', '소비자 물가지수', '5년 변동금리 모기지', '미국 달러 환율',
    '통화 공급량 M2', '가계 부채 비율', 'GDP 성장률',
    '나스닥 종합지수', 'S&P 500 지수', '금 가격', '달러 인덱스', '나스닥 100',
    'S&P 500 ETF', 'QQQ ETF', '러셀 2000 ETF', '다우 존스 ETF', 'VIX 지수',
    '닛케이 225', '상해종합', '항셍', '영국 FTSE', '독일 DAX', '프랑스 CAC 40',
    '미국 전체 채권시장 ETF', 'TIPS ETF', '투자등급 회사채 ETF', '달러/엔', '달러/위안',
    '미국 리츠 ETF'
]

# 실제 DB에서 로드된 컬럼에 없는 항목은 제외 (데이터 누락 방어)
TARGET_COLUMNS    = [c for c in TARGET_COLUMNS    if c in data.columns]
ECONOMIC_FEATURES = [c for c in ECONOMIC_FEATURES if c in data.columns]

print(f"예측 대상 종목 : {len(TARGET_COLUMNS)}개")
print(f"경제 지표 피처 : {len(ECONOMIC_FEATURES)}개")
print(f"LOOKBACK       : {LOOKBACK}일")
print(f"FORECAST_HORIZON: {FORECAST_HORIZON}일 후")
# Out:
# 예측 대상 종목 : 50개
# 경제 지표 피처 : 37개
# LOOKBACK       : 90일
# FORECAST_HORIZON: 14일 후

# %% [markdown]
# ## 5. 스케일링 및 데이터셋 구성

# %%
# 신경망은 입력값의 범위가 일정해야 학습이 잘 됩니다.
# MinMaxScaler: 각 컬럼의 최솟값→0, 최댓값→1 으로 변환 (0~1 정규화)
#
# 주가와 경제지표는 단위/스케일이 서로 달라 별도 스케일러를 사용합니다.
# 나중에 예측 결과를 원래 가격으로 되돌릴 때(inverse_transform) 이 스케일러가 필요합니다.

data_scaled  = data.copy()
stock_scaler = MinMaxScaler()   # 주가 전용 스케일러 (저장 대상)
econ_scaler  = MinMaxScaler()   # 경제지표 전용 스케일러 (저장 대상)

data_scaled[TARGET_COLUMNS]    = stock_scaler.fit_transform(data[TARGET_COLUMNS])
data_scaled[ECONOMIC_FEATURES] = econ_scaler.fit_transform(data[ECONOMIC_FEATURES])

print("스케일링 완료")
# Out:
# 스케일링 완료

# %%
X_stock_train, X_econ_train, y_train = [], [], []

for i in range(LOOKBACK, len(data_scaled) - FORECAST_HORIZON):
    X_stock_train.append(data_scaled[TARGET_COLUMNS].iloc[i-LOOKBACK:i].to_numpy())
    X_econ_train.append(data_scaled[ECONOMIC_FEATURES].iloc[i-LOOKBACK:i].to_numpy())
    y_train.append(data_scaled[TARGET_COLUMNS].iloc[i+FORECAST_HORIZON-1].to_numpy())

X_stock_train = np.array(X_stock_train)
X_econ_train  = np.array(X_econ_train)
y_train       = np.array(y_train)

# 최근 1달(약 30 거래일)을 validation으로 분리
VAL_SIZE = 30
X_stock_val, X_econ_val, y_val = X_stock_train[-VAL_SIZE:], X_econ_train[-VAL_SIZE:], y_train[-VAL_SIZE:]
X_stock_train, X_econ_train, y_train = X_stock_train[:-VAL_SIZE], X_econ_train[:-VAL_SIZE], y_train[:-VAL_SIZE]

print(f"학습셋  : {X_stock_train.shape}")   # (샘플수, LOOKBACK, 종목수)
print(f"검증셋  : {X_stock_val.shape}")     # (VAL_SIZE, LOOKBACK, 종목수)
print(f"y_train : {y_train.shape}")
# Out:
# 학습셋  : (7295, 90, 50)
# 검증셋  : (30, 90, 50)
# y_train : (7295, 50)

# %%
# 전체 구간 예측용 데이터셋 구성 (학습 후 결과 시각화/DB 저장에 사용)
#
# 학습셋과 달리 미래 정답(y)이 필요 없으므로
# FORECAST_HORIZON 제한 없이 모든 날짜에 대해 윈도우를 만듭니다.
# 이 데이터로 model.predict()를 호출하면 각 날짜에서 FORECAST_HORIZON일 뒤 예측값을 얻습니다.

X_stock_full, X_econ_full = [], []

for i in range(LOOKBACK, len(data_scaled)):
    X_stock_full.append(data_scaled[TARGET_COLUMNS].iloc[i-LOOKBACK:i].to_numpy())
    X_econ_full.append(data_scaled[ECONOMIC_FEATURES].iloc[i-LOOKBACK:i].to_numpy())

X_stock_full = np.array(X_stock_full)
X_econ_full  = np.array(X_econ_full)

print(f"X_stock_full : {X_stock_full.shape}")
print(f"X_econ_full  : {X_econ_full.shape}")
# Out:
# X_stock_full : (7339, 90, 50)
# X_econ_full  : (7339, 90, 37)

# %% [markdown]
# ## 6. Transformer 모델 정의 및 학습

# %%
def transformer_encoder(inputs, num_heads, ff_dim, dropout=0.3):
    attn = MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1])(inputs, inputs)
    attn = Dropout(dropout)(attn)
    attn = Add()([inputs, attn])
    attn = LayerNormalization(epsilon=1e-6)(attn)
    ffn  = Dense(ff_dim, activation="relu")(attn)
    ffn  = Dense(inputs.shape[-1])(ffn)
    ffn  = Dropout(dropout)(ffn)
    ffn  = Add()([attn, ffn])
    ffn  = LayerNormalization(epsilon=1e-6)(ffn)
    return ffn


def build_model(stock_shape, econ_shape, num_heads=8, ff_dim=256, num_layers=4):
    stock_in = Input(shape=stock_shape, name="stock_input")
    x = stock_in
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, ff_dim)
    x = Dense(64, activation="relu")(x)

    econ_in = Input(shape=econ_shape, name="econ_input")
    y = econ_in
    for _ in range(num_layers):
        y = transformer_encoder(y, num_heads, ff_dim)
    y = Dense(64, activation="relu")(y)

    merged = Add()([x, y])
    merged = Dense(128, activation="relu")(merged)
    merged = Dropout(0.4)(merged)
    merged = GlobalAveragePooling1D()(merged)
    output = Dense(stock_shape[1], name="output")(merged)
    return Model(inputs=[stock_in, econ_in], outputs=output)


print("모델 함수 정의 완료 (dropout=0.3/0.4)")
# Out:
# 모델 함수 정의 완료 (dropout=0.3/0.4)

# %%
# 입력 shape 정의
# stock_shape: (LOOKBACK일, 종목 수) — 주가 시퀀스
# econ_shape : (LOOKBACK일, 경제지표 수) — 경제지표 시퀀스
stock_shape = (LOOKBACK, len(TARGET_COLUMNS))
econ_shape  = (LOOKBACK, len(ECONOMIC_FEATURES))

model = build_model(stock_shape, econ_shape)

# loss='mse': 예측값과 실제값의 차이(제곱 평균)를 최소화
# mae: 평균 절대 오차 — 학습 중 참고용 지표
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])
model.summary()   # 레이어별 파라미터 수 출력
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ stock_input         │ (None, 90, 50)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ econ_input          │ (None, 90, 37)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ stock_input[0][0… │
# │ (MultiHeadAttentio… │                   │            │ stock_input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ econ_input[0][0], │
# │ (MultiHeadAttentio… │                   │            │ econ_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 90, 50)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 90, 50)    │          0 │ stock_input[0][0… │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 90, 37)    │          0 │ econ_input[0][0], │
# │                     │                   │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 90, 50)    │        100 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 90, 50)    │     12,850 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 90, 50)    │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 90, 37)    │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 90, 50)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 90, 50)    │     12,850 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 90, 50)    │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 90, 37)    │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 90, 50)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 90, 50)    │     12,850 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 90, 50)    │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 90, 37)    │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 50)    │     81,250 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 37)    │     44,733 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 90, 50)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 90, 37)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 90, 256)   │     13,056 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 90, 256)   │      9,728 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 90, 50)    │     12,850 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 90, 37)    │      9,509 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 90, 50)    │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 90, 37)    │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 90, 50)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 90, 37)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 50)    │        100 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 37)    │         74 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 90, 64)    │      3,264 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 90, 64)    │      2,432 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 90, 64)    │          0 │ dense_8[0][0],    │
# │                     │                   │            │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 90, 128)   │      8,320 │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 90, 128)   │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dropout_24[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 50)        │      6,450 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 706,362 (2.69 MB)
#  Trainable params: 706,362 (2.69 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

CKPT_PATH = os.path.join(MODEL_DIR, "best_checkpoint.keras")

model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])

print(f"학습 시작 (epochs={EPOCHS}, batch_size={BATCH_SIZE}, val=최근 {VAL_SIZE}일)...")
history = model.fit(
    [X_stock_train, X_econ_train],
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=([X_stock_val, X_econ_val], y_val),
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        ModelCheckpoint(CKPT_PATH, monitor='val_loss', save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1),
    ],
    verbose=1
)
print(f"학습 완료 (실제 학습 에포크: {len(history.history['loss'])})")
# Out:
# 학습 시작 (epochs=50, batch_size=32, val=최근 30일)...
# Epoch 1/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0923 - mae: 0.1990
# Epoch 1: val_loss improved from None to 0.06820, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 92s 174ms/step - loss: 0.0383 - mae: 0.1199 - val_loss: 0.0682 - val_mae: 0.2141 - learning_rate: 1.0000e-04
# Epoch 2/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0057 - mae: 0.0540
# Epoch 2: val_loss improved from 0.06820 to 0.04676, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 0.0051 - mae: 0.0507 - val_loss: 0.0468 - val_mae: 0.1706 - learning_rate: 1.0000e-04
# Epoch 3/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0040 - mae: 0.0444
# Epoch 3: val_loss improved from 0.04676 to 0.03570, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 0.0038 - mae: 0.0431 - val_loss: 0.0357 - val_mae: 0.1461 - learning_rate: 1.0000e-04
# Epoch 4/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0033 - mae: 0.0404
# Epoch 4: val_loss improved from 0.03570 to 0.02798, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0032 - mae: 0.0393 - val_loss: 0.0280 - val_mae: 0.1304 - learning_rate: 1.0000e-04
# Epoch 5/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0029 - mae: 0.0372
# Epoch 5: val_loss improved from 0.02798 to 0.02299, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0028 - mae: 0.0366 - val_loss: 0.0230 - val_mae: 0.1189 - learning_rate: 1.0000e-04
# Epoch 6/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0025 - mae: 0.0347
# Epoch 6: val_loss improved from 0.02299 to 0.02218, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0025 - mae: 0.0345 - val_loss: 0.0222 - val_mae: 0.1164 - learning_rate: 1.0000e-04
# Epoch 7/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0023 - mae: 0.0331
# Epoch 7: val_loss improved from 0.02218 to 0.01867, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - loss: 0.0022 - mae: 0.0327 - val_loss: 0.0187 - val_mae: 0.1023 - learning_rate: 1.0000e-04
# Epoch 8/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0020 - mae: 0.0314
# Epoch 8: val_loss did not improve from 0.01867
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0020 - mae: 0.0312 - val_loss: 0.0206 - val_mae: 0.1092 - learning_rate: 1.0000e-04
# Epoch 9/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019 - mae: 0.0303
# Epoch 9: val_loss did not improve from 0.01867
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0019 - mae: 0.0299 - val_loss: 0.0237 - val_mae: 0.1147 - learning_rate: 1.0000e-04
# Epoch 10/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0018 - mae: 0.0293
# Epoch 10: val_loss did not improve from 0.01867
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0017 - mae: 0.0288 - val_loss: 0.0199 - val_mae: 0.1079 - learning_rate: 1.0000e-04
# Epoch 11/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0016 - mae: 0.0281
# Epoch 11: val_loss improved from 0.01867 to 0.01746, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0016 - mae: 0.0278 - val_loss: 0.0175 - val_mae: 0.0981 - learning_rate: 5.0000e-05
# Epoch 12/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0015 - mae: 0.0270
# Epoch 12: val_loss did not improve from 0.01746
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 0.0015 - mae: 0.0272 - val_loss: 0.0216 - val_mae: 0.1104 - learning_rate: 5.0000e-05
# Epoch 13/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0015 - mae: 0.0269
# Epoch 13: val_loss did not improve from 0.01746
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0015 - mae: 0.0267 - val_loss: 0.0201 - val_mae: 0.1053 - learning_rate: 5.0000e-05
# Epoch 14/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0015 - mae: 0.0265
# Epoch 14: val_loss improved from 0.01746 to 0.01736, saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/best_checkpoint.keras
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 0.0014 - mae: 0.0263 - val_loss: 0.0174 - val_mae: 0.0993 - learning_rate: 5.0000e-05
# Epoch 15/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0014 - mae: 0.0258
# Epoch 15: val_loss did not improve from 0.01736
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0014 - mae: 0.0259 - val_loss: 0.0199 - val_mae: 0.1011 - learning_rate: 5.0000e-05
# Epoch 16/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0014 - mae: 0.0259
# Epoch 16: val_loss did not improve from 0.01736
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0014 - mae: 0.0256 - val_loss: 0.0227 - val_mae: 0.1137 - learning_rate: 5.0000e-05
# Epoch 17/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - mae: 0.0250
# Epoch 17: val_loss did not improve from 0.01736
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0013 - mae: 0.0251 - val_loss: 0.0235 - val_mae: 0.1151 - learning_rate: 5.0000e-05
# Epoch 18/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0245
# Epoch 18: val_loss did not improve from 0.01736
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0013 - mae: 0.0245 - val_loss: 0.0202 - val_mae: 0.1040 - learning_rate: 2.5000e-05
# Epoch 19/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0244
# Epoch 19: val_loss did not improve from 0.01736
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0013 - mae: 0.0244 - val_loss: 0.0217 - val_mae: 0.1086 - learning_rate: 2.5000e-05
# Epoch 20/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - mae: 0.0243
# Epoch 20: val_loss did not improve from 0.01736
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0012 - mae: 0.0241 - val_loss: 0.0194 - val_mae: 0.1045 - learning_rate: 2.5000e-05
# Epoch 21/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0238
# Epoch 21: val_loss did not improve from 0.01736
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 0.0012 - mae: 0.0238 - val_loss: 0.0214 - val_mae: 0.1091 - learning_rate: 1.2500e-05
# Epoch 22/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0012 - mae: 0.0235
# Epoch 22: val_loss did not improve from 0.01736
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0012 - mae: 0.0237 - val_loss: 0.0193 - val_mae: 0.1016 - learning_rate: 1.2500e-05
# Epoch 23/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0012 - mae: 0.0238
# Epoch 23: val_loss did not improve from 0.01736
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0012 - mae: 0.0236 - val_loss: 0.0198 - val_mae: 0.1042 - learning_rate: 1.2500e-05
# Epoch 24/50
# 227/228 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - mae: 0.0237
# Epoch 24: val_loss did not improve from 0.01736
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 0.0012 - mae: 0.0235 - val_loss: 0.0210 - val_mae: 0.1068 - learning_rate: 6.2500e-06
# 학습 완료 (실제 학습 에포크: 24)

# %% [markdown]
# ## 7. 모델 저장 (스케일러 포함)

# %%
import json

# 저장 파일 경로 정의
MODEL_PATH        = os.path.join(MODEL_DIR, "transformer_stock.keras")  # 학습된 모델
STOCK_SCALER_PATH = os.path.join(MODEL_DIR, "stock_scaler.pkl")          # 주가 스케일러
ECON_SCALER_PATH  = os.path.join(MODEL_DIR, "econ_scaler.pkl")           # 경제지표 스케일러
META_PATH         = os.path.join(MODEL_DIR, "model_meta.json")           # 메타정보

# 모델과 스케일러를 저장합니다
# 스케일러는 나중에 예측값을 원래 가격 단위로 복원(inverse_transform)할 때 반드시 필요합니다
model.save(MODEL_PATH)
joblib.dump(stock_scaler, STOCK_SCALER_PATH)
joblib.dump(econ_scaler,  ECON_SCALER_PATH)

# 메타 정보 저장: 모델을 나중에 불러와 사용할 때 필요한 설정값들
# (어떤 컬럼을 입력으로 썼는지, lookback이 얼마인지 등)
meta = {
    "target_columns"    : TARGET_COLUMNS,
    "economic_features" : ECONOMIC_FEATURES,
    "lookback"          : LOOKBACK,
    "forecast_horizon"  : FORECAST_HORIZON,
    "test_mode"         : TEST_MODE,
}
with open(META_PATH, "w", encoding="utf-8") as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

print(f"모델 저장     : {MODEL_PATH}")
print(f"스케일러 저장 : {STOCK_SCALER_PATH}, {ECON_SCALER_PATH}")
print(f"메타 저장     : {META_PATH}")
print(f"모델 용량 : {MODEL_PATH} ({os.path.getsize(MODEL_PATH) / 1024**2:.2f} MB)")
# Out:
# 모델 저장     : /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/transformer_stock.keras
# 스케일러 저장 : /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/stock_scaler.pkl, /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/econ_scaler.pkl
# 메타 저장     : /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/model_meta.json
# 모델 용량 : /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/transformer_stock.keras (8.54 MB)

# %% [markdown]
# ## 8. 예측 수행 및 DB 저장

# %%
# 전체 구간에 대해 예측을 수행합니다
# preds_scaled: 0~1 정규화된 예측값
# preds       : inverse_transform으로 실제 가격 단위로 복원

preds_scaled = model.predict([X_stock_full, X_econ_full], verbose=1)
preds        = stock_scaler.inverse_transform(preds_scaled)

# 예측값과 실제값을 날짜 기준으로 매핑합니다
# - dates : X_stock_full의 각 윈도우가 시작하는 날짜 (LOOKBACK 이후부터)
# - actual: 해당 날짜의 실제 주가 (비교용)
pred_len   = len(preds)
dates      = data['날짜'].iloc[LOOKBACK:LOOKBACK+pred_len].values
actual_end = min(LOOKBACK+pred_len, len(data))
actual     = data[TARGET_COLUMNS].iloc[LOOKBACK:actual_end].values

# 실제값 길이가 예측값보다 짧으면 NaN으로 패딩 (마지막 FORECAST_HORIZON행 구간)
if actual.shape[0] < pred_len:
    pad    = np.full((pred_len - actual.shape[0], len(TARGET_COLUMNS)), np.nan)
    actual = np.vstack([actual, pad])

# 결과 DataFrame 생성: 날짜별로 종목_Predicted / 종목_Actual 컬럼 쌍으로 구성
result_data = pd.DataFrame({'날짜': dates})
for idx, col in enumerate(TARGET_COLUMNS):
    result_data[f'{col}_Predicted'] = preds[:, idx]
    result_data[f'{col}_Actual']    = actual[:, idx]
result_data['날짜'] = pd.to_datetime(result_data['날짜']).dt.strftime('%Y-%m-%d')

print(f"예측 결과: {len(result_data)}행")
result_data.head(3)
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step
# 예측 결과: 7339행
# /tmp/ipykernel_5800/1749695016.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   result_data[f'{col}_Actual']    = actual[:, idx]
#            날짜  엔비디아_Predicted  엔비디아_Actual  구글 A_Predicted  구글 A_Actual  \
# 0  2006-04-01       -2.050121     0.477167       -4.368774     9.759760
# 1  2006-04-02       -2.032192     0.477167       -4.310009     9.759760
# 2  2006-04-03       -2.014325     0.482500       -4.250815     9.752252
#
#    애플_Predicted  애플_Actual  마이크로소프트_Predicted  마이크로소프트_Actual  아마존_Predicted  \
# 0     13.467473     2.2400          33.186985       27.209999       4.112412
# 1     13.529723     2.2400          33.183411       27.209999       4.076966
# 2     13.592094     2.2375          33.179829       27.559999       4.041878
#
#    ...  메리어트_Predicted  메리어트_Actual  메르카도리브레_Predicted  메르카도리브레_Actual  \
# 0  ...       49.593105    31.974987         -76.592705            28.5
# 1  ...       49.560856    31.974987         -76.911278            28.5
# 2  ...       49.528606    32.627537         -77.230156            28.5
#
#    ADP_Predicted  ADP_Actual  에어비앤비_Predicted  에어비앤비_Actual  몬델리즈_Predicted  \
# 0      17.595951   36.227169       145.804260    144.710007       32.857018
# 1      17.627932   36.227169       145.780792    144.710007       32.866413
# 2      17.660011   36.591976       145.757263    144.710007       32.875774
#
#    몬델리즈_Actual
# 0    30.309999
# 1    30.309999
# 2    30.280001
#
# [3 rows x 101 columns]

# %%
def save_predictions_to_db(df, chunk_size=100):
    """
    예측 결과를 Supabase의 predicted_stocks 테이블에 저장합니다.

    저장 전 기존 데이터를 전부 삭제하고 새 데이터로 교체합니다.
    (항상 최신 예측 결과만 유지)

    NaN/Inf 값은 DB에 저장 불가하므로 None으로 변환합니다.
    chunk_size 단위로 나눠서 insert (한 번에 너무 많으면 API 오류 방지)
    """
    import math
    records = []
    for _, row in df.iterrows():
        rec = {}
        for k, v in row.items():
            if isinstance(v, float) and (math.isnan(v) or math.isinf(v)):
                rec[k] = None   # NaN/Inf → None (DB에 NULL로 저장)
            else:
                rec[k] = v
        records.append(rec)

    # 기존 데이터 전체 삭제 후 새 데이터 삽입
    supabase_admin.table("predicted_stocks").delete().neq("id", 0).execute()
    for i in range(0, len(records), chunk_size):
        supabase_admin.table("predicted_stocks").insert(records[i:i+chunk_size]).execute()
    print(f"{len(records)}개 예측 결과 저장 완료")


save_predictions_to_db(result_data)
# Out:
# 7339개 예측 결과 저장 완료

# %% [markdown]
# ## 9. 학습 시각화

# %%
plt.figure(figsize=(10, 4))
plt.plot(history.history['loss'],     label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss (최근 30일)')
plt.title('Training vs Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5800/3850369089.py:8: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_5800/3850369089.py:8: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_5800/3850369089.py:8: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ---
#
# ## 10. 결과 분석 (저장된 모델 로드 후 평가)
#
# > 학습 없이 이 섹션부터 실행 가능 — 저장된 모델을 불러와서 분석

# %%
# 이 셀부터는 학습 없이 저장된 모델을 불러와서 분석만 수행합니다
# 이미 학습이 완료된 상태라면 위 학습 셀들을 건너뛰고 여기서부터 실행 가능합니다

loaded_model        = load_model(MODEL_PATH)
loaded_stock_scaler = joblib.load(STOCK_SCALER_PATH)
loaded_econ_scaler  = joblib.load(ECON_SCALER_PATH)

# 메타 정보 로드: 모델이 어떤 컬럼/설정으로 학습되었는지 확인
with open(META_PATH, encoding='utf-8') as f:
    meta = json.load(f)

print(f"모델 로드 완료: {MODEL_PATH}")
print(f"메타 정보: lookback={meta['lookback']}, forecast_horizon={meta['forecast_horizon']}")
print(f"종목 수: {len(meta['target_columns'])}개")
# Out:
# 모델 로드 완료: /content/drive/MyDrive/trader-ai/model/v4_260505_최근30일_validation/transformer_stock.keras
# 메타 정보: lookback=90, forecast_horizon=14
# 종목 수: 50개

# %%
def load_predictions_from_db(chunk_size=1000):
    """
    predicted_stocks 테이블에서 저장된 예측 결과를 로드합니다.
    Supabase 페이지 제한(1000행)을 고려해 offset을 이동하며 전체를 가져옵니다.
    """
    # 전체 행 수를 먼저 조회해서 반복 횟수 결정
    count_resp  = supabase.table("predicted_stocks").select("id", count="exact").execute()
    total_count = count_resp.count
    all_data    = []
    for offset in range(0, total_count, chunk_size):
        resp = (
            supabase.table("predicted_stocks")
            .select("*")
            .order("날짜", desc=False)
            .limit(chunk_size)
            .offset(offset)
            .execute()
        )
        all_data.extend(resp.data)
    df = pd.DataFrame(all_data)
    df['날짜'] = pd.to_datetime(df['날짜'])
    return df


pred_df = load_predictions_from_db()
print(f"예측 데이터 로드: {len(pred_df)}행")
pred_df.head(3)
# Out:
# 예측 데이터 로드: 7339행
#       id         날짜  엔비디아_Predicted  엔비디아_Actual  구글 A_Predicted  구글 A_Actual  \
# 0  22018 2006-04-01       -2.050121     0.477167       -4.368774     9.759760
# 1  22019 2006-04-02       -2.032192     0.477167       -4.310009     9.759760
# 2  22020 2006-04-03       -2.014325     0.482500       -4.250815     9.752252
#
#    애플_Predicted  애플_Actual  마이크로소프트_Predicted  마이크로소프트_Actual  ...  \
# 0     13.467473     2.2400          33.186985       27.209999  ...
# 1     13.529723     2.2400          33.183411       27.209999  ...
# 2     13.592094     2.2375          33.179829       27.559999  ...
#
#    메리어트_Actual  메르카도리브레_Predicted  메르카도리브레_Actual  ADP_Predicted  ADP_Actual  \
# 0    31.974987         -76.592705            28.5      17.595951   36.227169
# 1    31.974987         -76.911278            28.5      17.627932   36.227169
# 2    32.627537         -77.230156            28.5      17.660011   36.591976
#
#    에어비앤비_Predicted  에어비앤비_Actual  몬델리즈_Predicted  몬델리즈_Actual  \
# 0       145.804260    144.710007       32.857018    30.309999
# 1       145.780792    144.710007       32.866413    30.309999
# 2       145.757263    144.710007       32.875774    30.280001
#
#                          created_at
# 0  2026-05-05T10:26:37.373774+00:00
# 1  2026-05-05T10:26:37.373774+00:00
# 2  2026-05-05T10:26:37.373774+00:00
#
# [3 rows x 103 columns]

# %%
def evaluate_predictions(df, target_cols, horizon):
    """
    예측 정확도를 계산합니다.

    지표 설명:
      MAE       : 평균 절대 오차 (작을수록 좋음)
      RMSE      : 평균 제곱근 오차 (이상치에 민감, 작을수록 좋음)
      MAPE (%)  : 평균 절대 비율 오차 (실제값 대비 몇 % 틀렸는지)
      Accuracy  : 100 - MAPE (높을수록 좋음)

    주의: 예측값은 horizon일 뒤 주가이므로, 실제값도 horizon만큼 shift해서 비교합니다.
    TEST_MODE에서는 데이터가 부족해 비교 불가(Empty)가 정상입니다.
    """
    metrics = []
    for col in target_cols:
        pred_col   = f'{col}_Predicted'
        actual_col = f'{col}_Actual'
        if pred_col not in df.columns or actual_col not in df.columns:
            continue
        predicted = pd.to_numeric(df[pred_col], errors='coerce')
        actual    = pd.to_numeric(df[actual_col], errors='coerce').shift(-horizon)
        mask      = ~predicted.isna() & ~actual.isna()
        predicted, actual = predicted[mask], actual[mask]
        if len(predicted) == 0:
            continue
        mae  = mean_absolute_error(actual, predicted)
        rmse = mean_squared_error(actual, predicted) ** 0.5
        mape = (abs((actual - predicted) / actual).mean()) * 100
        metrics.append({
            'Stock'       : col,
            'MAE'         : round(mae, 4),
            'RMSE'        : round(rmse, 4),
            'MAPE (%)'    : round(mape, 2),
            'Accuracy (%)': round(100 - mape, 2)
        })
    result = pd.DataFrame(metrics)
    if result.empty:
        print("평가 데이터 부족 (테스트 모드에서는 정상)")
        return result
    return result.sort_values('Accuracy (%)', ascending=False)


eval_df = evaluate_predictions(pred_df, meta['target_columns'], meta['forecast_horizon'])
print("=== 성능 평가 ===")
eval_df
# Out:
# === 성능 평가 ===
#           Stock       MAE      RMSE  MAPE (%)  Accuracy (%)
# 48        에어비앤비    5.1468    7.4832      3.65         96.35
# 49         몬델리즈    2.5502    3.4685      5.61         94.39
# 22          Arm    4.8720    8.4607      6.04         93.96
# 23          펩시코    9.3832   10.7889      9.84         90.16
# 15          시스코    3.2832    3.9959     10.51         89.49
# 19   텍사스 인스트루먼트    7.6042   10.3578     10.54         89.46
# 12           인텔    3.3235    4.3674     10.61         89.39
# 20           린드   16.6681   21.5529     10.85         89.15
# 27           퀄컴    8.9796   11.3738     11.60         88.40
# 42         컴캐스트    2.1416    2.6471     11.86         88.14
# 35    허니웰 인터내셔널    9.7857   11.8419     12.18         87.82
# 24         티모바일    7.7738   11.1268     14.21         85.79
# 8           월마트    4.4809    5.5950     14.95         85.05
# 13         코스트코   30.2383   42.3258     16.35         83.65
# 40   버텍스 파마슈티컬스   17.6768   23.8186     16.63         83.37
# 47          ADP   13.0655   15.3490     17.69         82.31
# 3       마이크로소프트   18.5235   28.4766     17.92         82.08
# 28           암젠   17.5925   20.7001     18.09         81.91
# 37         스타벅스    5.2227    6.3284     18.52         81.48
# 25     아나로그디바이스   14.1439   18.7859     20.58         79.42
# 39         인튜이트   25.9489   38.7577     22.04         77.96
# 45         메리어트   13.4558   17.6677     22.18         77.82
# 34     마벨 테크놀로지    5.1137    6.8931     24.59         75.41
# 44         시놉시스   19.5133   28.2295     26.51         73.49
# 38   콘스텔레이션 에너지   15.9629   22.5616     27.04         72.96
# 31    인튜이티브 서지컬   20.5137   27.9341     28.03         71.97
# 33    팔로알토 네트웍스    7.3420   10.6056     29.72         70.28
# 41          어도비   29.5161   37.4340     29.81         70.19
# 36        부킹홀딩스    6.7264    8.9054     31.16         68.84
# 32          앱러빈   26.4186   35.9529     35.67         64.33
# 6            메타   25.8630   33.1319     35.75         64.25
# 18  어플라이드 머티리얼즈   11.1805   15.1212     36.72         63.28
# 1          구글 A   10.1522   13.6248     37.22         62.78
# 4           아마존    8.2444   11.2414     38.20         61.80
# 16         팔란티어    6.1131    9.1386     42.96         57.04
# 11         ASML   45.6753   59.0805     43.26         56.74
# 43         케이던스   11.8581   17.2417     43.48         56.52
# 30         씨게이트   19.4209   27.3744     54.03         45.97
# 17         램리서치    7.4852   10.4943     56.09         43.91
# 21     KLA Corp   47.5050   64.6289     62.78         37.22
# 26         샌디스크   27.3128   39.0423     68.43         31.57
# 10          AMD   10.0886   14.7411     70.88         29.12
# 2            애플   11.2770   14.3498     80.50         19.50
# 29         쇼피파이    6.5447   10.8805     83.01         16.99
# 46      메르카도리브레  128.7650  161.9717    107.09         -7.09
# 5          브로드컴   12.4724   16.9368    114.73        -14.73
# 9          마이크론   23.8221   28.6015    125.90        -25.90
# 14         넷플릭스    4.4652    5.6631    168.73        -68.73
# 7           테슬라   18.3648   25.7867    239.81       -139.81
# 0          엔비디아    8.9131   10.4979   1355.70      -1255.70

# %%
def analyze_rise(df, target_cols):
    """
    가장 최근 행 기준으로 각 종목의 상승/하락 여부와 등락률을 계산합니다.

    - Last Actual  : 가장 최근 실제 주가
    - Predicted    : 모델이 예측한 FORECAST_HORIZON일 뒤 주가
    - Rise         : 예측가 > 실제가 이면 True (상승 예측)
    - Rise Prob(%) : (예측가 - 실제가) / 실제가 × 100 (예상 등락률)

    트레이딩 앱에서 이 값을 참고해 매수 종목을 결정합니다.
    """
    last    = df.iloc[-1]   # 가장 최근 날짜 행
    results = []
    for col in target_cols:
        last_actual = last.get(f'{col}_Actual', np.nan)
        pred_future = last.get(f'{col}_Predicted', np.nan)
        if pd.notna(last_actual) and pd.notna(pred_future):
            rise = pred_future > last_actual
            prob = ((pred_future - last_actual) / last_actual) * 100
        else:
            rise, prob = np.nan, np.nan
        results.append({
            'Stock'        : col,
            'Last Actual'  : round(last_actual, 2) if pd.notna(last_actual) else np.nan,
            'Predicted'    : round(pred_future, 2) if pd.notna(pred_future) else np.nan,
            'Rise'         : rise,
            'Rise Prob (%)': round(prob, 2) if pd.notna(prob) else np.nan
        })
    return pd.DataFrame(results).sort_values('Rise Prob (%)', ascending=False)


rise_df = analyze_rise(pred_df, meta['target_columns'])
print("=== 상승/하락 예측 ===")
rise_df
# Out:
# === 상승/하락 예측 ===
#           Stock  Last Actual  Predicted   Rise  Rise Prob (%)
# 47          ADP       211.32     262.15   True          24.06
# 7           테슬라       392.51     444.19   True          13.17
# 24         티모바일       194.42     215.54   True          10.86
# 38   콘스텔레이션 에너지       321.05     345.22   True           7.53
# 28           암젠       323.85     344.28   True           6.31
# 16         팔란티어       146.03     154.67   True           5.92
# 23          펩시코       154.59     161.10   True           4.21
# 2            애플       276.83     285.69   True           3.20
# 20           린드       493.55     507.31   True           2.79
# 13         코스트코      1012.79    1030.49   True           1.75
# 18  어플라이드 머티리얼즈       391.38     394.12   True           0.70
# 31    인튜이티브 서지컬       452.35     435.76  False          -3.67
# 49         몬델리즈        61.38      58.65  False          -4.45
# 33    팔로알토 네트웍스       184.56     174.86  False          -5.26
# 32          앱러빈       475.00     445.31  False          -6.25
# 45         메리어트       347.24     322.05  False          -7.26
# 3       마이크로소프트       413.62     381.04  False          -7.88
# 8           월마트       130.33     119.80  False          -8.08
# 48        에어비앤비       138.86     126.84  False          -8.65
# 29         쇼피파이       127.55     115.65  False          -9.33
# 35    허니웰 인터내셔널       209.59     189.84  False          -9.43
# 37         스타벅스       104.97      94.17  False         -10.29
# 36        부킹홀딩스       165.58     145.97  False         -11.84
# 25     아나로그디바이스       397.02     348.57  False         -12.20
# 15          시스코        92.63      80.87  False         -12.69
# 0          엔비디아       198.48     170.21  False         -14.24
# 17         램리서치       258.57     219.73  False         -15.02
# 14         넷플릭스        91.02      76.84  False         -15.58
# 1          구글 A       383.25     318.38  False         -16.93
# 39         인튜이트       406.99     330.96  False         -18.68
# 11         ASML      1386.21    1122.06  False         -19.06
# 19   텍사스 인스트루먼트       280.89     224.07  False         -20.23
# 41          어도비       253.96     201.15  False         -20.80
# 40   버텍스 파마슈티컬스       429.85     324.93  False         -24.41
# 43         케이던스       349.51     263.51  False         -24.61
# 44         시놉시스       497.50     374.92  False         -24.64
# 4           아마존       272.05     203.36  False         -25.25
# 46      메르카도리브레      1813.53    1324.91  False         -26.94
# 6            메타       610.41     442.79  False         -27.46
# 10          AMD       341.54     232.25  False         -32.00
# 34     마벨 테크놀로지       163.66     107.86  False         -34.10
# 22          Arm       203.26     133.53  False         -34.31
# 5          브로드컴       416.50     270.42  False         -35.07
# 21     KLA Corp      1713.32    1052.17  False         -38.59
# 42         컴캐스트        27.07      16.49  False         -39.08
# 9          마이크론       576.45     342.48  False         -40.59
# 27           퀄컴       168.38      92.62  False         -44.99
# 12           인텔        95.78      51.68  False         -46.05
# 26         샌디스크      1255.86     624.46  False         -50.28
# 30         씨게이트       738.54     345.43  False         -53.23

# %%
def get_recommendation(row):
    """
    상승 확률에 따라 매수/매도 추천 등급을 반환합니다.
      STRONG BUY : 상승 예측 + 등락률 2% 초과
      BUY        : 상승 예측 + 등락률 0~2%
      SELL       : 하락 예측 또는 데이터 없음
    """
    prob = row.get('Rise Prob (%)', 0)
    rise = row.get('Rise', False)
    if pd.isna(prob) or pd.isna(rise):
        return "No Data"
    if rise and prob > 2:
        return "STRONG BUY"
    elif rise and prob > 0:
        return "BUY"
    return "SELL"


# 성능 평가(eval_df)와 상승분석(rise_df)을 종목 기준으로 합칩니다
if eval_df.empty or rise_df.empty:
    final = rise_df.copy() if not rise_df.empty else eval_df.copy()
else:
    final = pd.merge(eval_df, rise_df, on='Stock', how='outer')

final['Recommendation'] = final.apply(get_recommendation, axis=1)
final = final.sort_values('Rise Prob (%)', ascending=False) if 'Rise Prob (%)' in final.columns else final

print("=== 최종 리포트 ===")
show_cols = [c for c in ['Stock', 'Accuracy (%)', 'Rise Prob (%)', 'Recommendation'] if c in final.columns]
final[show_cols]
# Out:
# === 최종 리포트 ===
#           Stock  Accuracy (%)  Rise Prob (%) Recommendation
# 0           ADP         82.31          24.06     STRONG BUY
# 43          테슬라       -139.81          13.17     STRONG BUY
# 45         티모바일         85.79          10.86     STRONG BUY
# 41   콘스텔레이션 에너지         72.96           7.53     STRONG BUY
# 27           암젠         81.91           6.31     STRONG BUY
# 46         팔란티어         57.04           5.92     STRONG BUY
# 48          펩시코         90.16           4.21     STRONG BUY
# 28           애플         19.50           3.20     STRONG BUY
# 8            린드         89.15           2.79     STRONG BUY
# 40         코스트코         83.65           1.75            BUY
# 31  어플라이드 머티리얼즈         63.28           0.70            BUY
# 37    인튜이티브 서지컬         71.97          -3.67           SELL
# 15         몬델리즈         94.39          -4.45           SELL
# 47    팔로알토 네트웍스         70.28          -5.26           SELL
# 29          앱러빈         64.33          -6.25           SELL
# 13         메리어트         77.82          -7.26           SELL
# 10      마이크로소프트         82.08          -7.88           SELL
# 34          월마트         85.05          -8.08           SELL
# 32        에어비앤비         96.35          -8.65           SELL
# 20         쇼피파이         16.99          -9.33           SELL
# 49    허니웰 인터내셔널         87.82          -9.43           SELL
# 21         스타벅스         81.48         -10.29           SELL
# 17        부킹홀딩스         68.84         -11.84           SELL
# 25     아나로그디바이스         79.42         -12.20           SELL
# 23          시스코         89.49         -12.69           SELL
# 33         엔비디아      -1255.70         -14.24           SELL
# 7          램리서치         43.91         -15.02           SELL
# 6          넷플릭스        -68.73         -15.58           SELL
# 5          구글 A         62.78         -16.93           SELL
# 36         인튜이트         77.96         -18.68           SELL
# 2          ASML         56.74         -19.06           SELL
# 44   텍사스 인스트루먼트         89.46         -20.23           SELL
# 30          어도비         70.19         -20.80           SELL
# 16   버텍스 파마슈티컬스         83.37         -24.41           SELL
# 39         케이던스         56.52         -24.61           SELL
# 22         시놉시스         73.49         -24.64           SELL
# 26          아마존         61.80         -25.25           SELL
# 12      메르카도리브레         -7.09         -26.94           SELL
# 14           메타         64.25         -27.46           SELL
# 1           AMD         29.12         -32.00           SELL
# 9      마벨 테크놀로지         75.41         -34.10           SELL
# 3           Arm         93.96         -34.31           SELL
# 18         브로드컴        -14.73         -35.07           SELL
# 4      KLA Corp         37.22         -38.59           SELL
# 38         컴캐스트         88.14         -39.08           SELL
# 11         마이크론        -25.90         -40.59           SELL
# 42           퀄컴         88.40         -44.99           SELL
# 35           인텔         89.39         -46.05           SELL
# 19         샌디스크         31.57         -50.28           SELL
# 24         씨게이트         45.97         -53.23           SELL

# %%
def save_analysis_to_db(df, chunk_size=100):
    """
    최종 분석 결과(추천 등급, 상승 확률 등)를 stock_analysis_results 테이블에 저장합니다.
    이 테이블이 트레이딩 앱의 매수 판단에 직접 사용됩니다.

    - 컬럼명을 DB 스키마에 맞게 rename 후 저장
    - NaN/Inf → None 변환 (DB NULL)
    - bool/numpy 타입 → Python 기본 타입 변환
    - 기존 데이터 전체 삭제 후 새 데이터로 교체
    """
    import math
    col_map = {
        'Stock'           : 'Stock',
        'MAE'             : 'MAE',
        'RMSE'            : 'RMSE',
        'MAPE (%)'        : 'MAPE (%)',
        'Accuracy (%)'    : 'Accuracy (%)',
        'Last Actual'     : 'Last Actual Price',
        'Predicted'       : 'Predicted Future Price',
        'Rise'            : 'Predicted Rise',
        'Rise Prob (%)'   : 'Rise Probability (%)',
        'Recommendation'  : 'Recommendation'
    }
    save_df = df.rename(columns=col_map)
    records = []
    for _, row in save_df.iterrows():
        rec = {}
        for k, v in row.items():
            if isinstance(v, float) and (math.isnan(v) or math.isinf(v)):
                rec[k] = None
            elif hasattr(v, 'item'):   # numpy 타입 → Python 기본 타입
                rec[k] = v.item()
            else:
                rec[k] = v
        records.append(rec)

    supabase_admin.table("stock_analysis_results").delete().neq("id", 0).execute()
    for i in range(0, len(records), chunk_size):
        supabase_admin.table("stock_analysis_results").insert(records[i:i+chunk_size]).execute()
    print(f"{len(records)}개 분석 결과 저장 완료")


save_analysis_to_db(final)
print("\n=== 모든 작업 완료 ===")
# Out:
# 50개 분석 결과 저장 완료
#
# === 모든 작업 완료 ===
